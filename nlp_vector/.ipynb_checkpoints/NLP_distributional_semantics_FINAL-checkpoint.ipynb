# %% [markdown]
# # NLP Project: Vector Space Semantics for Similarity between Eastenders Characters
#
# In this project, I will be creating a vector representation of a document containing lines spoken by a character in the Eastenders script data (i.e. from the file `training.csv`), then improving that representation such that each character vector is maximially distinguished from the other character documents. This distinction is measured by how well a simple information retrieval classification method can select documents from validation and test data as belonging to the correct class of document (i.e. deciding which character spoke the lines by measuring the similarity of those document vectors to those built in training).
#
# As the lines are not evenly distributed in terms of frequency, this project stipulates that only a maximum of the first **400 lines** of each character in the training data is allowed to create the training documents, and a maximum of the first **40 lines** in the test data (from `test.csv`). This makes it more challenging, as number of lines spoken by a character can't be used directly or otherwise as a feature.
#
# I will improve the character vector representations by pre-processing, feature extraction and transformation techniques.

# %%
import string
import re
import numpy as np
from numpy.linalg import norm
import pandas as pd
from collections import Counter, OrderedDict

import seaborn as sns
import matplotlib.pyplot as plt

import nltk

from sklearn.feature_extraction import DictVectorizer

# %matplotlib inline
pd.options.display.max_colwidth=500

# %%
# Load in training data and display in pandas dataframe
train_path='training.csv'
all_train_data = pd.read_csv(train_path,  delimiter="\t", skip_blank_lines = True)
test_path ='test.csv'
test_data = pd.read_csv(test_path,  delimiter="\t", skip_blank_lines = True)

# Inspect
all_train_data
# Out:
#        Episode  Scene                   Scene_info Character_name  \
# 0         1350      1  DESERTED CAR PARK EXT NIGHT        SHIRLEY
# 1         1350      1  DESERTED CAR PARK EXT NIGHT          OTHER
# 2         1350      2                R&R INT NIGHT           JACK
# 3         1350      2                R&R INT NIGHT         RONNIE
# 4         1350      2                R&R INT NIGHT           JACK
# ...        ...    ...                          ...            ...
# 15314     1399     55         SQUARE EXT DAY LIGHT          OTHER
# 15315     1399     55         SQUARE EXT DAY LIGHT            MAX
# 15316     1399     55         SQUARE EXT DAY LIGHT          OTHER
# 15317     1399     55         SQUARE EXT DAY LIGHT            MAX
# 15318     1399     55         SQUARE EXT DAY LIGHT          OTHER
#
#                                                                                                               Line  \
# 0                                               Look at ya, not a mark on ya. And you think you're an unlucky man.
# 1                                                                                                         Shirl...
# 2                                                         Oi. Where have you been? Huh? What were the texts about?
# 3                                                          Nothing. Nothing. I'll be with you in two minutes yeah?
# 4            Well I've got mates here I wanted to have a chat with them, instead I've been serving behind the bar.
# ...                                                                                                            ...
# 15314  Dad? Okay ... alright, just one drink alright. But that's all. It doesn't mean anything. It's just a drink.
# 15315                                                   Thanks Bradley. Thanks mate... It means the world to me...
# 15316                                                                                               You alright...
# 15317                                                                                  Yeah, yeah, yeah. I'm fine.
# 15318                                                                                           Well, let me know.
#
#        Gender
# 0      FEMALE
# 1        MALE
# 2        MALE
# 3      FEMALE
# 4        MALE
# ...       ...
# 15314    MALE
# 15315    MALE
# 15316    MALE
# 15317    MALE
# 15318    MALE
#
# [15319 rows x 6 columns]

# %%
#Inspect
test_data
# Out:
#       Episode  Scene                           Scene_info Character_name  \
# 0        1350      7          DESERTED CAR PARK EXT NIGHT        SHIRLEY
# 1        1350      7          DESERTED CAR PARK EXT NIGHT          OTHER
# 2        1350      7          DESERTED CAR PARK EXT NIGHT        SHIRLEY
# 3        1350      7          DESERTED CAR PARK EXT NIGHT          OTHER
# 4        1350      7          DESERTED CAR PARK EXT NIGHT        SHIRLEY
# ...       ...    ...                                  ...            ...
# 1762     1398     32              GEORGE STREET EXT NIGHT           JANE
# 1763     1399     27  [NAME] & [NAME]'S BEDROOM INT NIGHT          TANYA
# 1764     1399     27  [NAME] & [NAME]'S BEDROOM INT NIGHT          OTHER
# 1765     1399     27  [NAME] & [NAME]'S BEDROOM INT NIGHT          TANYA
# 1766     1399     27  [NAME] & [NAME]'S BEDROOM INT NIGHT          OTHER
#
#                                                                                                                                                                                       Line  \
# 0     You'll be alright Kevin. They're gonna cut you out. It's going to be alright. Come on, just talk to me. Just, just talk to me. Call me names- let me know you're still here with me.
# 1                                                                                                                                              ...I've got pins and needles in my fingers.
# 2                                                                                                                                                                         That's the cold.
# 3                                                                                                                                                            Yeah. It's all shutting down.
# 4                                                                                                                                                                      It's just the cold.
# ...                                                                                                                                                                                    ...
# 1762                                                                                           I know. Now Ian come on. Everything's going to be alright. It is. It's going to be alright.
# 1763                                                                                                                                                         Night night baby. I love you.
# 1764                                                                                                                                                                         Love you too.
# 1765                                                                                            Let's get that under your ankle shall we. Careful, alright? Night night darling. Love you.
# 1766                                                                                                                                                                         Love you Mum.
#
#       Gender
# 0     FEMALE
# 1       MALE
# 2     FEMALE
# 3       MALE
# 4     FEMALE
# ...      ...
# 1762  FEMALE
# 1763  FEMALE
# 1764  FEMALE
# 1765  FEMALE
# 1766  FEMALE
#
# [1767 rows x 6 columns]

# %%
# Split into training and test data for heldout validation with random samples of 9:1 train/heldout split
from random import shuffle, seed

seed(0) # set a seed for reproducibility so same split is used each time

epsiode_scene_column = all_train_data.Episode.astype(str) + "-" + all_train_data.Scene.astype(str)
all_train_data['episode_scene'] = epsiode_scene_column
episode_scenes = sorted(list(set([x for x in epsiode_scene_column.values]))) # set function is random, need to sort!

shuffle(episode_scenes)

print(len(episode_scenes))
episode_split = int(0.9*len(episode_scenes))
training_ep_scenes = episode_scenes[:episode_split]
test_ep_scenes = episode_scenes[episode_split:]
print(len(training_ep_scenes), len(test_ep_scenes))

def train_or_heldout_eps(val):
    if val in training_ep_scenes:
        return "training"
    return "heldout"

all_train_data['train_heldout'] = all_train_data['episode_scene'].apply(train_or_heldout_eps)
# Out:
# 1394
# 1254 140

# %%
print('Raw Data: ',np.shape(all_train_data))
train_data = all_train_data[all_train_data['train_heldout']=='training']
val_data = all_train_data[all_train_data['train_heldout']=='heldout']
print('Train set: ',np.shape(train_data))
print('Validation set: ',np.shape(val_data))
# Out:
# Raw Data:  (15319, 8)
# Train set:  (13638, 8)
# Validation set:  (1681, 8)

# %%
train_data
# Out:
#        Episode  Scene                   Scene_info Character_name  \
# 0         1350      1  DESERTED CAR PARK EXT NIGHT        SHIRLEY
# 1         1350      1  DESERTED CAR PARK EXT NIGHT          OTHER
# 2         1350      2                R&R INT NIGHT           JACK
# 3         1350      2                R&R INT NIGHT         RONNIE
# 4         1350      2                R&R INT NIGHT           JACK
# ...        ...    ...                          ...            ...
# 15314     1399     55         SQUARE EXT DAY LIGHT          OTHER
# 15315     1399     55         SQUARE EXT DAY LIGHT            MAX
# 15316     1399     55         SQUARE EXT DAY LIGHT          OTHER
# 15317     1399     55         SQUARE EXT DAY LIGHT            MAX
# 15318     1399     55         SQUARE EXT DAY LIGHT          OTHER
#
#                                                                                                               Line  \
# 0                                               Look at ya, not a mark on ya. And you think you're an unlucky man.
# 1                                                                                                         Shirl...
# 2                                                         Oi. Where have you been? Huh? What were the texts about?
# 3                                                          Nothing. Nothing. I'll be with you in two minutes yeah?
# 4            Well I've got mates here I wanted to have a chat with them, instead I've been serving behind the bar.
# ...                                                                                                            ...
# 15314  Dad? Okay ... alright, just one drink alright. But that's all. It doesn't mean anything. It's just a drink.
# 15315                                                   Thanks Bradley. Thanks mate... It means the world to me...
# 15316                                                                                               You alright...
# 15317                                                                                  Yeah, yeah, yeah. I'm fine.
# 15318                                                                                           Well, let me know.
#
#        Gender episode_scene train_heldout
# 0      FEMALE        1350-1      training
# 1        MALE        1350-1      training
# 2        MALE        1350-2      training
# 3      FEMALE        1350-2      training
# 4        MALE        1350-2      training
# ...       ...           ...           ...
# 15314    MALE       1399-55      training
# 15315    MALE       1399-55      training
# 15316    MALE       1399-55      training
# 15317    MALE       1399-55      training
# 15318    MALE       1399-55      training
#
# [13638 rows x 8 columns]

# %%
val_data
# Out:
#        Episode  Scene                         Scene_info Character_name  \
# 56        1350     18         BRANNINGS' HOUSE INT NIGHT          TANYA
# 57        1350     18         BRANNINGS' HOUSE INT NIGHT            MAX
# 58        1350     18         BRANNINGS' HOUSE INT NIGHT           SEAN
# 59        1350     18         BRANNINGS' HOUSE INT NIGHT          TANYA
# 60        1350     18         BRANNINGS' HOUSE INT NIGHT            MAX
# ...        ...    ...                                ...            ...
# 15268     1399     29  [NAME] & [NAME]'S HOUSE INT NIGHT         STACEY
# 15269     1399     29  [NAME] & [NAME]'S HOUSE INT NIGHT          TANYA
# 15270     1399     29  [NAME] & [NAME]'S HOUSE INT NIGHT         STACEY
# 15271     1399     29  [NAME] & [NAME]'S HOUSE INT NIGHT          TANYA
# 15272     1399     29  [NAME] & [NAME]'S HOUSE INT NIGHT         STACEY
#
#                                                                                                                                                                                                                                        Line  \
# 56                                                                                                                                                                                                                              Who's that?
# 57                                                                                                                                                                           Tanya! Tanya it's me. I wanna give Oscar a New Year kiss. Tan?
# 58                                                                                                                                                                                                                 Right. I'll have a word.
# 59                                                                                                                                                 No no no leave it, leave it. He ain't got a key. He'll go away. Do you want some crisps?
# 60                               Who, who you got in there, Tan? Tan, I've got a right to know who my kids are being exposed to. I bet you ain't got anyone have ya? You're just sitting there with a bottle of wine all on your Jack, Tan?
# ...                                                                                                                                                                                                                                     ...
# 15268  I asked him to leave you. I asked him again and again. I begged him. And if he had. I'd have been with him. I'd have been with him now. So it might suit you to think that it was all Max but it wasn't, not really, not in the end.
# 15269                                                                                                                                                                                                       Why you telling me all this eh?
# 15270                                                                                                Because I don't want you using Sean to punish him, I don't want you wrecking your family cause of me. I just, I just want it all over.
# 15271                                                                                                                                                       It is over. It's all over. Will you please just go home now and leave me alone.
# 15272                                                                                                                                                                                                                        Just tell him.
#
#        Gender episode_scene train_heldout
# 56     FEMALE       1350-18       heldout
# 57       MALE       1350-18       heldout
# 58       MALE       1350-18       heldout
# 59     FEMALE       1350-18       heldout
# 60       MALE       1350-18       heldout
# ...       ...           ...           ...
# 15268  FEMALE       1399-29       heldout
# 15269  FEMALE       1399-29       heldout
# 15270  FEMALE       1399-29       heldout
# 15271  FEMALE       1399-29       heldout
# 15272  FEMALE       1399-29       heldout
#
# [1681 rows x 8 columns]

# %%
if False:
    # A simpler alternative to the above, but where a high split means some characters
    # may be left out
    print('Raw Data: ',np.shape(all_train_data))
    idx = int(0.9 * np.shape(all_train_data)[0])
    train_data = all_train_data[:idx]
    val_data = all_train_data[idx:]
    print('Train set: ',np.shape(train_data))
    print('Validation set: ',np.shape(val_data))

# %%
# Create one document per character
def create_character_document_from_dataframe(df, max_line_count):
    """Returns a dict with the name of the character as key,
    their lines joined together as a single string, with end of line _EOL_
    markers between them.
    
    ::max_line_count:: the maximum number of lines to be added per character
    """
    character_docs = {}
    character_line_count = {}
    character_gender = {}
    for line, name, gender in zip(df.Line, df.Character_name, df.Gender):
        
        if not name in character_docs.keys():
            character_docs[name] = ""
            character_line_count[name] = 0
        if character_line_count[name]==max_line_count:
            continue
        character_docs[name] += str(line)   + " _EOL_ "
        
        character_line_count[name]+=1
        
    #obtain name gender mapping info for Q2
    for name, gender in zip(df.Character_name, df.Gender):
        if name != "OTHER": #as other has diff gender, do not extract its gender
            character_gender[name] =str(gender)
                
    print("name-gender mapping: ", character_gender)
    print("\nlines per character", character_line_count)
    return character_docs

# %%
# print out the number of words each character has in the training set
# only use the first 360 lines of each character
train_character_docs = create_character_document_from_dataframe(train_data, max_line_count=360)
print('Num. Characters: ',len(train_character_docs.keys()),"\n")
total_words = 0
for name in train_character_docs.keys():
    print(name, 'Number of Words: ',len(train_character_docs[name].split()))
    total_words += len(train_character_docs[name].split())
print("total words", total_words)
# Out:
# name-gender mapping:  {'SHIRLEY': 'FEMALE', 'JACK': 'MALE', 'RONNIE': 'FEMALE', 'TANYA': 'FEMALE', 'SEAN': 'MALE', 'ROXY': 'FEMALE', 'HEATHER': 'FEMALE', 'MAX': 'MALE', 'IAN': 'MALE', 'JANE': 'FEMALE', 'STACEY': 'FEMALE', 'PHIL': 'MALE', 'MINTY': 'MALE', 'CHRISTIAN': 'MALE', 'CLARE': 'FEMALE'}
#
# lines per character {'SHIRLEY': 360, 'OTHER': 360, 'JACK': 360, 'RONNIE': 360, 'TANYA': 360, 'SEAN': 360, 'ROXY': 360, 'HEATHER': 360, 'MAX': 360, 'IAN': 360, 'JANE': 360, 'STACEY': 360, 'PHIL': 360, 'MINTY': 360, 'CHRISTIAN': 342, 'CLARE': 352}
# Num. Characters:  16
#
# SHIRLEY Number of Words:  3848
# OTHER Number of Words:  3244
# JACK Number of Words:  4435
# RONNIE Number of Words:  3442
# TANYA Number of Words:  3786
# SEAN Number of Words:  3637
# ROXY Number of Words:  3838
# HEATHER Number of Words:  4098
# MAX Number of Words:  4363
# IAN Number of Words:  4332
# JANE Number of Words:  3648
# STACEY Number of Words:  3913
# PHIL Number of Words:  3635
# MINTY Number of Words:  4005
# CHRISTIAN Number of Words:  3738
# CLARE Number of Words:  4344
# total words 62306

# %%
train_character_docs
# Out:
# {'SHIRLEY': 'Look at ya, not a mark on ya. And you think you\'re an unlucky man. _EOL_ I\'m gonna get help. Oh where\'s my phone? Oh Kevin. Kevin you smashed it, didn\'t ya? Kevin, Kevin, where\'s your phone? _EOL_ No you\'re not, ssh, shut up. _EOL_ Fire brigade and ambulance. There\'s been an accident. On an industrial estate in Walford. ...Um, the Marsh Lane industrial estate. Please come quick. My husband- he\'s not my husband- my friend. He\'s trapped in the car. Please come quick... Shirley Carter. 82 82B George Street, Walford, E20. Please hurry, please come quick. _EOL_ Kevin. Kevin! _EOL_ Kevin I\'m gonna go to the main road - _EOL_ To make sure they know where to go. _EOL_ Kevin I\'ll be five minutes. _EOL_ You\'ll be fine. You\'re talking. I\'ll be five minutes. _EOL_ It\'s alright, it\'s alright, it\'s alright, it\'s alright. _EOL_ Go away. _EOL_ I don\'t know what to say. It\'s a nightmare. _EOL_ He asked me to go with him. _EOL_ Yeah. _EOL_ Between us? Of course not. _EOL_ We just went to get Yolande\'s window fixed. _EOL_ I don\'t know. It\'s New Years Eve, people might\'ve vandalised it. _EOL_ Didn\'t they tell you? _EOL_ Well, I really don\'t want to go into details- _EOL_ We were driving along and the bonnet flew up. _EOL_ Maybe it wasn\'t shut properly. I don\'t know. It just happ
ewhere to slip out of my clothes... and Ian kindly stepped in. _EOL_ Well he said you never wore it. _EOL_ Well, it's a little bit loose, but it's nothing a belt won't sort... _EOL_ I might just do that. _EOL_ I really ought to be going. _EOL_ Trust me Jane. I'm doing you a favour here. _EOL_ I can get one myself. _EOL_ No no no. I don't need any handouts, Ian. _EOL_ Look, I've gotta be somewhere... _EOL_ Hello, Dot. _EOL_ It's so great to see you. _EOL_ ... Dot, I've really gotta be going. _EOL_ I'll tell you what. Next time I'm in Walford... I'll comes and stay for a _EOL_ That Ian's doing alright, hasn't he? For someone that owns a poxy cafe. _EOL_ Do you know what? _EOL_ I'm not in a rush to be anywhere. _EOL_ You're the closest thing I've got to family Dot. I'd do anything for you. _EOL_ You've done enough. _EOL_ Thanks Dot but I really should be moving on. I've got _EOL_ The trouble is...I'm a bit short on cash.. _EOL_ Really.... _EOL_ Alright, I will. _EOL_ Just thought I'd return this. _EOL_ Not exactly my style. _EOL_ Fine thanks. She's been really kind. _EOL_ That kind of depends on you. _EOL_ If I'm gonna stay around, I need some work. So I was wondering.... _EOL_ You know what? I don't think it's really me do you? I'm used to working in a more sophisticated environment. _EOL_ How dare you! _EOL_ I tried really hard. I don't think Jane likes me very much. Think maybe it's best if I move on after all. _EOL_ Tanya? _EOL_ Sorry about that madam. _EOL_ Yes. Loads of times. _EOL_ It might stink a little bit. _EOL_ Just forgot my scarf. _EOL_ D'you want me to get that for you? _EOL_ I've done reception work before. _EOL_ Good afternoon Booty. Yep, just one moment Mrs Finlay. I'll just check for you. Mrs George? If you'd like to take a seat someone will be with you shortly. Sorry to keep you waiting. We can offer you 11.30 or 2.30. Whichever's better for you. That's fine. Ok, that's in the diary. Any problems, give us a call. Look forward to seeing you then. _EOL_ Nice uniform. _EOL_ Looking forward to your first day? _EOL_ Just trying to be friendly. _EOL_ Morning Tanya. Where shall I put my coat? _EOL_ See you then, bye. Gaynor needs someone to sweep up. And I'll have a coffee please. Milk. No sugar. _EOL_ And I say you do. _EOL_ Tanya doesn't pay you to sit around on your... _EOL_ Fine. I will. But I'll be having a word with Tanya about your aggressive attitude. _EOL_ Was it definitely 12 o' clock? I'm really sorry about this... there seems to be some kind of mix up...Excuse me a moment... I've got a regular claiming I booked her in with Gaynor this morning and that I offered all of her friends a 50% discount. Do you know anything about it? _EOL_ Look, Tanya's gonna be back in a minute. I need you to stay here an ...

# %% [markdown]
# # Task 1. Improve pre-processing

# %% [markdown]
# ### Answer: To avoid confusion, please kindly run the above codes from the beginning of the notebook before 'pre_process()' section, after that please run all the rest codes from here:

# %% [markdown]
#  - Main changes for Q1 have been made in the below pre_process1() function. Instead of simply tokenizing text based on white space, I have experimented various techniques including:
# - 1) white space split token
# - 2) change to lower case
# - 3) remove 'eol' characters
# - 4) remove punctuations
# - 5) remove stop words
# - 6) implement stemming
#
#    and obtained the best performance in terms of a mean rank and accuracy.
#    The most optimal techniques used here are: 1) to 6) except 3). (Please note in this function, POS taggings are also generated for later tasks. It has not been used in this task)
#
# - In the very last of the code in this question, the final solution and results from different experiments are shown. I have achieved the best result: a mean rank - 3.3125 and accuracy 0.625. The result has shown a great improvement from a mean rank of 5.12 and accuracy of 0.3125 originally.

# %%
#Task 1 updated tokenize with POS tags generated （POS tags to be used for Q2)
#what it does to the text: pos tag generated, lower case, 
#remove punctuation, remove stop words, word stemming

# import and download relative libraries for tokenize
from nltk.corpus import stopwords
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.tokenize import sent_tokenize, word_tokenize
nltk.download('punkt')
from nltk.stem import PorterStemmer
ps = PorterStemmer()
import nltk
nltk.download('averaged_perceptron_tagger')

def pre_process1(character_text):

    wordlist = []
    poslist= []

    #change to lower case
    character_text = character_text.lower() 
    
    #remove '_eol_'
    #character_text = character_text.replace("_eol_ ","")
    
    #generate pos tags
    tokens = word_tokenize(character_text)
    wordpos = nltk.pos_tag(tokens)

    #remove punctuation
    symbols = "!#$%&()*+-.,/:;<=>?@[\]^`{|}~\n"
    j=0
    for i in range(len(wordpos)):
        for symbol in symbols:
            if wordpos[i-j][0] == symbol:    
                del wordpos[i-j]
                j += 1
              
        
    #remove stop words
    stops = stopwords.words('english')
    k=0
    for i in range(len(wordpos)):
        for stop in stops:
            if wordpos[i-k][0] == stop:    
                del wordpos[i-k]
                k += 1

    for i in range(len(wordpos)):
        word = wordpos[i][0]
        pos = wordpos[i][1]
        wordlist.append(word)
        poslist.append(pos)
 

    #stemming
    wordlist2 = []
    for w in wordlist:
        wordlist2.append(ps.stem(w))
    

    return wordlist2, poslist
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\dandi\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\dandi\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\dandi\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
# create list of pairs of (character name, pre-processed character) 
training_corpus = [(name, pre_process1(doc)[0]) for name, doc in sorted(train_character_docs.items())]
train_labels = [name for name, doc in training_corpus]

# %%
# create list of pairs of (character name, pre-processed pos tags)
training_POS = [(name, pre_process1(doc)[1]) for name, doc in sorted(train_character_docs.items())]

# %%
#modified v1.5 - for q1 no new features added yet
import nltk
nltk.download('averaged_perceptron_tagger')
def to_feature_vector_dictionary1(character_doc, tag):
    """Converts a list of pre-processed tokens and extra features
    to a Dictionary as a function of the tokens.
    
    Initially just a simple count. Improve this for Q2.
    
    ::character_doc:: a list of pre-processed tokens
    ::extra_features:: any extra features for the character to be added to feature vector dict
    """
    

    #poslist = nltk.pos_tag(character_doc)
    #print(tag)

    counts = Counter(character_doc)  # for now a simple count
    counts = dict(counts)
    #pos = Counter(tag)
    #pos = dict(pos)
    #counts.update(pos)

    return counts
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\dandi\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
#updated version3
corpusVectorizer = DictVectorizer()   # corpusVectorizor which will just produce sparse vectors from feature dicts
# Any matrix transformers (e.g. tf-idf transformers) should be initialized here


def create_document_matrix_from_corpus1(corpus,tag, fitting=False):
    """Method which fits different vectorizers
    on data and returns a matrix.
    
    Currently just does simple conversion to matrix by vectorizing the dictionary. Improve this for Q3.
    
    ::corpus:: a list of (class_label, document) pairs.
    ::fitting:: a boolean indicating whether to fit/train the vectorizers (should be true on training data)
    """
    
    # uses the global variable of the corpus Vectorizer to improve things
    if fitting:
        corpusVectorizer.fit([to_feature_vector_dictionary1(a[1],b[1]) for a, b in zip(corpus,tag)])
    doc_feature_matrix = corpusVectorizer.transform([to_feature_vector_dictionary1(a[1],b[1]) for a, b in zip(corpus,tag)])
    
    #training_feature_matrix[0].toarray()
    return doc_feature_matrix

training_feature_matrix = create_document_matrix_from_corpus1(training_corpus, training_POS, fitting=True)

# %%
training_feature_matrix
# Out:
# <16x3284 sparse matrix of type '<class 'numpy.float64'>'
# 	with 10378 stored elements in Compressed Sparse Row format>

# %%
# get the validation data- only 40 lines used for each character
val_character_docs = create_character_document_from_dataframe(val_data, max_line_count=40)
print('Num. Characters: ',len(val_character_docs.keys()),"\n")
total_words = 0
for name in val_character_docs.keys():
    print(name, 'Num of Words: ',len(val_character_docs[name].split()))
    total_words += len(val_character_docs[name].split())
print("total words", total_words)

# create list of pairs of (character name, pre-processed character) 
val_corpus = [(name, pre_process1(doc)[0]) for name, doc in sorted(val_character_docs.items())]
val_labels = [name for name, doc in val_corpus]
# create list of pairs of (character name, POS tags) 
val_POS = [(name, pre_process1(doc)[1]) for name, doc in sorted(val_character_docs.items())]
# Out:
# name-gender mapping:  {'TANYA': 'FEMALE', 'MAX': 'MALE', 'SEAN': 'MALE', 'SHIRLEY': 'FEMALE', 'STACEY': 'FEMALE', 'RONNIE': 'FEMALE', 'JACK': 'MALE', 'PHIL': 'MALE', 'IAN': 'MALE', 'JANE': 'FEMALE', 'ROXY': 'FEMALE', 'HEATHER': 'FEMALE', 'MINTY': 'MALE', 'CHRISTIAN': 'MALE', 'CLARE': 'FEMALE'}
#
# lines per character {'TANYA': 40, 'MAX': 40, 'SEAN': 35, 'SHIRLEY': 40, 'OTHER': 40, 'STACEY': 40, 'RONNIE': 40, 'JACK': 40, 'PHIL': 40, 'IAN': 40, 'JANE': 40, 'ROXY': 40, 'HEATHER': 40, 'MINTY': 40, 'CHRISTIAN': 40, 'CLARE': 40}
# Num. Characters:  16
#
# TANYA Num of Words:  438
# MAX Num of Words:  737
# SEAN Num of Words:  366
# SHIRLEY Num of Words:  329
# OTHER Num of Words:  357
# STACEY Num of Words:  412
# RONNIE Num of Words:  464
# JACK Num of Words:  351
# PHIL Num of Words:  475
# IAN Num of Words:  508
# JANE Num of Words:  458
# ROXY Num of Words:  392
# HEATHER Num of Words:  411
# MINTY Num of Words:  470
# CHRISTIAN Num of Words:  489
# CLARE Num of Words:  405
# total words 7062

# %%
# Just transform the val_feature_matrix, don't fit
val_feature_matrix = create_document_matrix_from_corpus1(val_corpus,val_POS, fitting=False)

# %%
val_feature_matrix
# Out:
# <16x3284 sparse matrix of type '<class 'numpy.float64'>'
# 	with 2071 stored elements in Compressed Sparse Row format>

# %%
def compute_cosine_similarity(v1, v2):
    """Takes a pair of vectors v1 and v2 (1-d arrays e.g. [0, 0.5, 0.5])
    returns the cosine similarity between the vectors
    """
    
    # compute cosine similarity manually
    manual_cosine_similarity = np.dot(v1, v2)  /(norm(v1) * norm(v2))
    
    return manual_cosine_similarity

# %%
def compute_IR_evaluation_scores(train_feature_matrix, test_feature_matrix, train_labels, test_labels):
    """
    Computes an information retrieval based on training data feature matrix and test data feature matrix
    returns 4-tuple:
    ::mean_rank:: mean of the ranking of the target document in terms of similarity to the query/test document
    1 is the best possible score.
    ::mean_cosine_similarity:: mean cosine similarity score for the target document vs. the test document of the same class
    ::accuracy:: proportion of test documents correctly classified
    ::df:: a data frame with all the similarity measures of the test documents vs. train documents
    
    params:
    ::train_feature_matrix:: a numpy matrix N x M shape where N = number of characters M = number of features
    ::test_feature_matrix::  a numpy matrix N x M shape where N = number of characters M = number of features
    ::train_labels:: a list of character names for the training data in order consistent with train_feature_matrix
    ::test_labels:: a list of character names for the test data in order consistent with test_feature_matrix
    """
    rankings = []
    all_cosine_similarities = []
    pairwise_cosine_similarity = []
    pairs = []
    correct = 0
    for i, target in enumerate(test_labels):
        # compare the left out character against the mean
        idx = i 
        fm_1 = test_feature_matrix.toarray()[idx]
        all_sims = {}
        # print("target:", target)
        for j, other in enumerate(train_labels):
            fm_2 = train_feature_matrix.toarray()[j]
            manual_cosine_similarity = compute_cosine_similarity(fm_1, fm_2)
            pairs.append((target, other))
            pairwise_cosine_similarity.append(manual_cosine_similarity)
            if other == target:
                all_cosine_similarities.append(manual_cosine_similarity)
            all_sims[other] = manual_cosine_similarity

            # print(target, other, manual_cosine_similarity)
        sorted_similarities = sorted(all_sims.items(),key=lambda x:x[1],reverse=True)
        # print(sorted_similarities)
        ranking = {key[0]: rank for rank, key in enumerate(sorted_similarities, 1)}
        # print("Ranking for target", ranking[target])
        if ranking[target] == 1:
            correct += 1
        rankings.append(ranking[target])
        # print("*****")
    mean_rank = np.mean(rankings)
    mean_cosine_similarity = np.mean(all_cosine_similarities)
    accuracy = correct/len(test_labels)
    print("mean rank", np.mean(rankings))
    print("mean cosine similarity", mean_cosine_similarity)
    print(correct, "correct out of", len(test_labels), "/ accuracy:", accuracy )
    
    # get a dafaframe showing all the similarity scores of training vs test docs
    df = pd.DataFrame({'doc1': [x[0] for x in pairs], 'doc2': [x[1] for x in pairs],
                       'similarity': pairwise_cosine_similarity})

    # display characters which are most similar and least similar
    df.loc[[df.similarity.values.argmax(), df.similarity.values.argmin()]]
    return (mean_rank, mean_cosine_similarity, accuracy, df)

# %%
def plot_heat_map_similarity(df):
    """Takes a dataframe with header 'doc1, doc2, similarity'
    Plots a heatmap based on the similarity scores.
    """
    test_labels =  sorted(list(set(df.sort_values(['doc1'])['doc1'])))
    # add padding 1.0 values to either side
    cm = [[1.0,] * (len(test_labels)+2)]
    for target in test_labels:
        new_row = [1.0]
        for x in df.sort_values(['doc1', 'doc2'])[df['doc1']==target]['similarity']:
            new_row.append(x)
        new_row.append(1.0)
        cm.append(new_row)
    cm.append([1.0,] * (len(test_labels)+2))
    #print(cm)
    labels = [""] + test_labels + [""]
    fig = plt.figure(figsize=(20,20))
    ax = fig.add_subplot(111)
    cax = ax.matshow(cm)
    plt.title('Similarity matrix between documents as vectors')
    fig.colorbar(cax)
    ax.set_xticks(np.arange(len(labels)))
    ax.set_yticks(np.arange(len(labels)))
    ax.set_xticklabels( labels, rotation=45)
    ax.set_yticklabels( labels)

    for i in range(len(cm)):
        for j in range(len(cm)):

            text = ax.text(j, i, round(cm[i][j],3),
                           ha="center", va="center", color="w")

    plt.xlabel('Training Vector Doc')
    plt.ylabel('Test Vector Doc')
    #fig.tight_layout()
    plt.show()

# %% [markdown]
# ### The best final performance result for Task 1 is shown below. And all the experiments and their results I have tried for pre_process() have also been listed below in the pasted text form.

# %%
mean_rank, mean_cosine_simliarity, acc, df = compute_IR_evaluation_scores(training_feature_matrix, val_feature_matrix, train_labels, val_labels)
# Out:
# mean rank 3.3125
# mean cosine similarity 0.936508444550048
# 10 correct out of 16 / accuracy: 0.625

# %% [markdown]
# The different techniques I have tried including:
# 1) white space split token
# 2) change to lower case
# 3) remove 'eol' characters
# 4) remove punctuations
# 5) remove stop words
# 6) implement stemming
#
# The experiments on different technique combinations are recorded here (note I will just use the technique number):

# %% [markdown]
# Experiment 1 1)&2):
# mean rank 3.25
# mean cosine similarity 0.9499481211709341
# 7 correct out of 16 / accuracy: 0.4375

# %% [markdown]
# Experiment 2 1) to 3): mean rank 2.4375
# mean cosine similarity 0.9375237501739655
# 6 correct out of 16 / accuracy: 0.375

# %% [markdown]
# Experiment 3 1) to 4): mean rank 3.25
# mean cosine similarity 0.8773615723233157
# 5 correct out of 16 / accuracy: 0.3125

# %% [markdown]
# Experiment 4 1) to 5): mean rank 3.3125
# mean cosine similarity 0.7560947346501452
# 8 correct out of 16 / accuracy: 0.5

# %% [markdown]
# Experiment5 1) to 6): mean rank 3.3125 mean cosine similarity 0.7560947346501452 8 correct out of 16 / accuracy: 0.5

# %% [markdown]
# Experiment 6 1) to 6) except 5: mean rank 3.0625
# mean cosine similarity 0.8782763997283665
# 6 correct out of 16 / accuracy: 0.375

# %% [markdown]
# Experiment 7 1) to 6) except 3: mean rank 3.3125
# mean cosine similarity 0.936508444550048
# 10 correct out of 16 / accuracy: 0.625

# %% [markdown]
# According to the above experiments, despite experiment 2 returned the best score of mean rank, I think it is not very generalised to exclude all other techniques, and by looking at experiment 7 it returns a fairly good rank and highest in accuracy. I have used experiment 7's technique as my final solution to pre_process() in the end.

# %% [markdown]
# # Task 2. Improve linguistic feature extraction
# Use the feature extraction techniques to improve the `to_feature_vector_dictionary` function.

# %% [markdown]
# ### Answer: To avoid confusion, please kindly run the above codes from the beginning of the notebook before 'pre_process()' section, after that please run all the rest codes from here:
#
# Main changes for Task 2 have been made for to_feature_vector_dictionary2() function. Initially, it is just a simple count of the tokens. After experimenting many things including:
# - POS tags
# - previous word followed by current word
# - current word followed by the next word, and many other combinations for word and its POS tags up to the length of 3
# - gender feature
# - sentiment score for each word
#
# The features used to achieve the best mean rank and accuracy are: 1)current word&tag. And I have achievement improvement to 2.4375 here.
#
# In addition, I use SelectKBest to find the best features, and I found out when k=5100 the model has improved more to 1.6875. And this is my final result for this question.
#
# In the last part of the code in this task, result for each experiment is shown in details

# %%
#Task 2 version3 
# import and download relative libraries for tokenize
from nltk.corpus import stopwords
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.tokenize import sent_tokenize, word_tokenize
nltk.download('punkt')
from nltk.stem import PorterStemmer
ps = PorterStemmer()
import nltk
nltk.download('averaged_perceptron_tagger')



def pre_process1(character_text):


    
    wordlist = []
    poslist= []

    #change to lower case
    character_text = character_text.lower()
        
    #remove '_eol_'
    #character_text = character_text.replace("_eol_ ","")
    
    #generate pos tags
    tokens = word_tokenize(character_text)
    wordpos = nltk.pos_tag(tokens)
    
    #remove punctuation
    symbols = "!#$%&()*@+-.,/:;<=>?[\]^`{|}~\n"
    j=0
    for i in range(len(wordpos)):
        for symbol in symbols:
            if wordpos[i-j][0] == symbol:    
                del wordpos[i-j]
                j += 1
              
        
    #remove stop words
    stops = stopwords.words('english')
    k=0
    for i in range(len(wordpos)):
        for stop in stops:
            if wordpos[i-k][0] == stop:    
                del wordpos[i-k]
                k += 1

    for i in range(len(wordpos)):
        word = wordpos[i][0]
        pos = wordpos[i][1]
        wordlist.append(word)
        poslist.append(pos)
 

    #stemming
    wordlist2 = []
    for w in wordlist:
        wordlist2.append(ps.stem(w))
    

    return wordlist2, poslist
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\dandi\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\dandi\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\dandi\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
# create list of pairs of (character name, pre-processed character) 
training_corpus = [(name, pre_process1(doc)[0]) for name, doc in sorted(train_character_docs.items())]
train_labels = [name for name, doc in training_corpus]

# %%
# create list of pairs of (character name, pre-processed pos tags)
training_POS = [(name, pre_process1(doc)[1]) for name, doc in sorted(train_character_docs.items())]

# %%
#training_corpus

# %% [markdown]
# Main changes for Task 2 has been made for the below to_feature_vector_dictionary2() function. Initially, it is just a simple count of the tokens. After experimenting many things including POS tags, previous word followed by current word, current word followed by the next word, and many other combinations for word up to length of 3, gender feature, sentiment score feature, the features used to achieve the best mean rank and accuracy are: current word&tag. Detailed experiment results are shown at the later part of the code.

# %%
#modified v3

import nltk
nltk.download('averaged_perceptron_tagger')
# !pip3 install afinn
from afinn import Afinn

def to_feature_vector_dictionary2(character_doc, tag, name):

    wordlist1 = [] #list store previous bigram

    senti_list = [] #list store sentiment scores for each token


    #counts = Counter(character_doc)  # for now a simple count
    #counts = dict(counts)
    counts = {}
    
    #add POS tag features
    #pos = Counter(tag)
    #pos = dict(pos)
    #counts.update(pos)
    
    #sentiment score analysis for each word
    afinn = Afinn()
    for j in character_doc:
        word_senti =  str(afinn.score(j))
        senti_list.append(word_senti)
    
    #experiment1 target word and its tag
    '''for i in range(len(character_doc)):
        word = character_doc[i] +'@'+ tag[i]
        wordlist1.append(word)

    word_counts = Counter(wordlist1)
    word_counts = dict(word_counts)
    for a in word_counts:
        counts[a] = 0
        counts[a] +=1'''
    
    #experiment2 target word and one prev word&tag
    '''for i in range(len(character_doc)):
        if i>0:
            word = character_doc[i-1] +'@'+ tag[i-1]+'_'+character_doc[i]+'@'+tag[i]
            wordlist1.append(word)

    word_counts = Counter(wordlist1)
    word_counts = dict(word_counts)
    for a in word_counts:
        counts[a] = 0
        counts[a] +=1'''
        
    #experiment 3 target word and one after word&tag
    '''for i in range(len(character_doc)):        
            if len(character_doc)-i>1:
                word = character_doc[i] +'@'+tag[i]+'_' + character_doc[i+1]+'@'+tag[i+1]    
            wordlist1.append(word)

    word_counts = Counter(wordlist1)
    word_counts = dict(word_counts)
    for a in word_counts:
        counts[a] = 0
        counts[a] +=1'''
        
    #experiment4 target and one after word
    '''for i in range(len(character_doc)):        
            if len(character_doc)-i>1:
                word = character_doc[i] +'_' + character_doc[i+1]    
            wordlist1.append(word)

    word_counts = Counter(wordlist1)
    word_counts = dict(word_counts)
    for a in word_counts:
        counts[a] = 0
        counts[a] +=1'''
    
    #experiment 5 target and one prev word
    '''for i in range(len(character_doc)):
        if i>0:
            word = character_doc[i-1] +'_'+character_doc[i]
            wordlist1.append(word)

    word_counts = Counter(wordlist1)
    word_counts = dict(word_counts)
    for a in word_counts:
        counts[a] = 0
        counts[a] +=1'''
    
    #experiment 6 target and one prev word and sentiment score
    '''for i in range(len(character_doc)):
        if i>0:
            word = character_doc[i-1] +'@'+ senti_list[i-1]+'_'+character_doc[i]+'@'+senti_list[i]
            wordlist1.append(word)

    word_counts = Counter(wordlist1)
    word_counts = dict(word_counts)
    for a in word_counts:
        counts[a] = 0
        counts[a] +=1'''
        
    #experiment 7 target word, tag and separated counter for gender i.e add another key and value - gender:1 for male
    for i in range(len(character_doc)):
        word = character_doc[i] +'@'+ tag[i]
        wordlist1.append(word)

    word_counts = Counter(wordlist1)
    word_counts = dict(word_counts)
    for a in word_counts:
        counts[a] = 0
        counts[a] +=1  

    
    #add gender feature, male=1, female=0
    #gender = 0
    #genders ={'SHIRLEY': 'FEMALE', 'JACK': 'MALE', 'RONNIE': 'FEMALE', 'TANYA': 'FEMALE', 'SEAN': 'MALE', 'ROXY': 'FEMALE', 'HEATHER': 'FEMALE', 'MAX': 'MALE', 'IAN': 'MALE', 'JANE': 'FEMALE', 'STACEY': 'FEMALE', 'PHIL': 'MALE', 'MINTY': 'MALE', 'CHRISTIAN': 'MALE', 'CLARE': 'FEMALE'}

    #for item in genders:
        #if name == item:
            #gender = genders[name]
            #if gender == "MALE":
                #gender =1
            #else: gender =0
    #counts.update({"Gender": gender})
    
    return counts
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\dandi\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# Requirement already satisfied: afinn in c:\users\dandi\anaconda3\lib\site-packages (0.1)

# %% [markdown]
# A little changes have been made here:

# %%
#updated version3
# changes made from original version: tag and name are parsed to 
#to_feature_vector_dictionary2()

corpusVectorizer = DictVectorizer()   # corpusVectorizor which will just produce sparse vectors from feature dicts

def create_document_matrix_from_corpus2(corpus,tag, fitting=False):
    """Method which fits different vectorizers
    on data and returns a matrix.
    
    Currently just does simple conversion to matrix by vectorizing the dictionary. Improve this for Q3.
    
    ::corpus:: a list of (class_label, document) pairs.
    ::fitting:: a boolean indicating whether to fit/train the vectorizers (should be true on training data)
    """
    
    # uses the global variable of the corpus Vectorizer to improve things
    if fitting:
        corpusVectorizer.fit([to_feature_vector_dictionary2(a[1],b[1],a[0]) for a, b in zip(corpus,tag)])

    doc_feature_matrix = corpusVectorizer.transform([to_feature_vector_dictionary2(a[1],b[1],a[0]) for a, b, in zip(corpus,tag)])
    
    #training_feature_matrix[0].toarray()
    return doc_feature_matrix

training_feature_matrix = create_document_matrix_from_corpus2(training_corpus, training_POS, fitting=True)

# %%
training_feature_matrix
# Out:
# <16x5426 sparse matrix of type '<class 'numpy.float64'>'
# 	with 13893 stored elements in Compressed Sparse Row format>

# %%
# get the validation data- only 40 lines used for each character
val_character_docs = create_character_document_from_dataframe(val_data, max_line_count=40)
print('Num. Characters: ',len(val_character_docs.keys()),"\n")
total_words = 0
for name in val_character_docs.keys():
    print(name, 'Num of Words: ',len(val_character_docs[name].split()))
    total_words += len(val_character_docs[name].split())
print("total words", total_words)

# create list of pairs of (character name, pre-processed character) 
val_corpus = [(name, pre_process1(doc)[0]) for name, doc in sorted(val_character_docs.items())]
val_labels = [name for name, doc in val_corpus]
# create list of pairs of (character name, POS tags) 
val_POS = [(name, pre_process1(doc)[1]) for name, doc in sorted(val_character_docs.items())]
# create list of pairs of (character name, sentiment score) 
#val_senti = [(name, pre_process1(doc)[2]) for name, doc in sorted(val_character_docs.items())]
# Out:
# name-gender mapping:  {'TANYA': 'FEMALE', 'MAX': 'MALE', 'SEAN': 'MALE', 'SHIRLEY': 'FEMALE', 'STACEY': 'FEMALE', 'RONNIE': 'FEMALE', 'JACK': 'MALE', 'PHIL': 'MALE', 'IAN': 'MALE', 'JANE': 'FEMALE', 'ROXY': 'FEMALE', 'HEATHER': 'FEMALE', 'MINTY': 'MALE', 'CHRISTIAN': 'MALE', 'CLARE': 'FEMALE'}
#
# lines per character {'TANYA': 40, 'MAX': 40, 'SEAN': 35, 'SHIRLEY': 40, 'OTHER': 40, 'STACEY': 40, 'RONNIE': 40, 'JACK': 40, 'PHIL': 40, 'IAN': 40, 'JANE': 40, 'ROXY': 40, 'HEATHER': 40, 'MINTY': 40, 'CHRISTIAN': 40, 'CLARE': 40}
# Num. Characters:  16
#
# TANYA Num of Words:  438
# MAX Num of Words:  737
# SEAN Num of Words:  366
# SHIRLEY Num of Words:  329
# OTHER Num of Words:  357
# STACEY Num of Words:  412
# RONNIE Num of Words:  464
# JACK Num of Words:  351
# PHIL Num of Words:  475
# IAN Num of Words:  508
# JANE Num of Words:  458
# ROXY Num of Words:  392
# HEATHER Num of Words:  411
# MINTY Num of Words:  470
# CHRISTIAN Num of Words:  489
# CLARE Num of Words:  405
# total words 7062

# %%
# Just transform the val_feature_matrix, don't fit
val_feature_matrix = create_document_matrix_from_corpus2(val_corpus,val_POS, fitting=False)

# %%
val_feature_matrix
# Out:
# <16x5426 sparse matrix of type '<class 'numpy.float64'>'
# 	with 2300 stored elements in Compressed Sparse Row format>

# %%
def compute_cosine_similarity(v1, v2):
    """Takes a pair of vectors v1 and v2 (1-d arrays e.g. [0, 0.5, 0.5])
    returns the cosine similarity between the vectors
    """
    
    # compute cosine similarity manually
    manual_cosine_similarity = np.dot(v1, v2)  /(norm(v1) * norm(v2))
    
    return manual_cosine_similarity

# %%
def compute_IR_evaluation_scores(train_feature_matrix, test_feature_matrix, train_labels, test_labels):
    """
    Computes an information retrieval based on training data feature matrix and test data feature matrix
    returns 4-tuple:
    ::mean_rank:: mean of the ranking of the target document in terms of similarity to the query/test document
    1 is the best possible score.
    ::mean_cosine_similarity:: mean cosine similarity score for the target document vs. the test document of the same class
    ::accuracy:: proportion of test documents correctly classified
    ::df:: a data frame with all the similarity measures of the test documents vs. train documents
    
    params:
    ::train_feature_matrix:: a numpy matrix N x M shape where N = number of characters M = number of features
    ::test_feature_matrix::  a numpy matrix N x M shape where N = number of characters M = number of features
    ::train_labels:: a list of character names for the training data in order consistent with train_feature_matrix
    ::test_labels:: a list of character names for the test data in order consistent with test_feature_matrix
    """
    rankings = []
    all_cosine_similarities = []
    pairwise_cosine_similarity = []
    pairs = []
    correct = 0
    for i, target in enumerate(test_labels):
        # compare the left out character against the mean
        idx = i 
        fm_1 = test_feature_matrix.toarray()[idx]
        all_sims = {}
        # print("target:", target)
        for j, other in enumerate(train_labels):
            fm_2 = train_feature_matrix.toarray()[j]
            manual_cosine_similarity = compute_cosine_similarity(fm_1, fm_2)
            pairs.append((target, other))
            pairwise_cosine_similarity.append(manual_cosine_similarity)
            if other == target:
                all_cosine_similarities.append(manual_cosine_similarity)
            all_sims[other] = manual_cosine_similarity

            # print(target, other, manual_cosine_similarity)
        sorted_similarities = sorted(all_sims.items(),key=lambda x:x[1],reverse=True)
        # print(sorted_similarities)
        ranking = {key[0]: rank for rank, key in enumerate(sorted_similarities, 1)}
        # print("Ranking for target", ranking[target])
        if ranking[target] == 1:
            correct += 1
        rankings.append(ranking[target])
        # print("*****")
    mean_rank = np.mean(rankings)
    mean_cosine_similarity = np.mean(all_cosine_similarities)
    accuracy = correct/len(test_labels)
    print("mean rank", np.mean(rankings))
    print("mean cosine similarity", mean_cosine_similarity)
    print(correct, "correct out of", len(test_labels), "/ accuracy:", accuracy )
    
    # get a dafaframe showing all the similarity scores of training vs test docs
    df = pd.DataFrame({'doc1': [x[0] for x in pairs], 'doc2': [x[1] for x in pairs],
                       'similarity': pairwise_cosine_similarity})

    # display characters which are most similar and least similar
    df.loc[[df.similarity.values.argmax(), df.similarity.values.argmin()]]
    return (mean_rank, mean_cosine_similarity, accuracy, df)

# %%
def plot_heat_map_similarity(df):
    """Takes a dataframe with header 'doc1, doc2, similarity'
    Plots a heatmap based on the similarity scores.
    """
    test_labels =  sorted(list(set(df.sort_values(['doc1'])['doc1'])))
    # add padding 1.0 values to either side
    cm = [[1.0,] * (len(test_labels)+2)]
    for target in test_labels:
        new_row = [1.0]
        for x in df.sort_values(['doc1', 'doc2'])[df['doc1']==target]['similarity']:
            new_row.append(x)
        new_row.append(1.0)
        cm.append(new_row)
    cm.append([1.0,] * (len(test_labels)+2))
    #print(cm)
    labels = [""] + test_labels + [""]
    fig = plt.figure(figsize=(20,20))
    ax = fig.add_subplot(111)
    cax = ax.matshow(cm)
    plt.title('Similarity matrix between documents as vectors')
    fig.colorbar(cax)
    ax.set_xticks(np.arange(len(labels)))
    ax.set_yticks(np.arange(len(labels)))
    ax.set_xticklabels( labels, rotation=45)
    ax.set_yticklabels( labels)

    for i in range(len(cm)):
        for j in range(len(cm)):

            text = ax.text(j, i, round(cm[i][j],3),
                           ha="center", va="center", color="w")

    plt.xlabel('Training Vector Doc')
    plt.ylabel('Test Vector Doc')
    #fig.tight_layout()
    plt.show()

# %% [markdown]
# ### Evaluation starts here: step 1: when trying different experiments, the best result is Experiment 1 using word&tag only. Result: mean rank improved from Task 1's 3.3125 to 2.4375 here. All other experiments results are shown below in pasted text.

# %%
mean_rank, mean_cosine_simliarity, acc, df = compute_IR_evaluation_scores(training_feature_matrix, val_feature_matrix, train_labels, val_labels)
# Out:
# mean rank 2.4375
# mean cosine similarity 0.28423874228754586
# 10 correct out of 16 / accuracy: 0.625

# %% [markdown]
# Experiment 1: target word and tag mean rank 2.4375
# mean cosine similarity 0.28423874228754586
# 10 correct out of 16 / accuracy: 0.625

# %% [markdown]
# Experiment 2: target word and one previous word and tag: mean rank 3.125
# mean cosine similarity 0.09022084210078041
# 9 correct out of 16 / accuracy: 0.5625

# %% [markdown]
# Experiment 3: target word and one after word and tag: mean rank 3.125
# mean cosine similarity 0.09022084210078041
# 9 correct out of 16 / accuracy: 0.5625

# %% [markdown]
# Experiment 4: target and one after word and tag: mean rank 2.6875
# mean cosine similarity 0.13292936839498484
# 9 correct out of 16 / accuracy: 0.5625

# %% [markdown]
# Experiment 5: target and one previous word mean rank 2.6875
# mean cosine similarity 0.13292936839498484
# 9 correct out of 16 / accuracy: 0.5625

# %% [markdown]
# Experiment 6: target and one previous word&sentiment score mean rank 2.6875
# mean cosine similarity 0.13292936839498484
# 9 correct out of 16 / accuracy: 0.5625

# %% [markdown]
# Experiment 7: target word and tag, and separated counter for gender i.e add another key and value - gender:1 for male
#
# mean rank 2.4375
# mean cosine similarity 0.28423874228754586
# 10 correct out of 16 / accuracy: 0.625

# %% [markdown]
# ### Evaluation step 2: experimenting with SelectKBest function to find the best features for the model, I found the best k=5100 with mean rank 1.6875.

# %%
#for loop to iterate different k to find the best features 
from sklearn.feature_selection import SelectKBest, chi2
for i in range(0,training_feature_matrix.shape[1],50):
    if i>0:
        selector =  SelectKBest(chi2,k=i)
        training_feature_matrix2 = selector.fit(training_feature_matrix, train_labels)
        features_train_transformed = selector.transform(training_feature_matrix)
    
        #val_feature_matrix2 = selector.fit(val_feature_matrix, val_labels)
        features_val_transformed = selector.transform(val_feature_matrix)
        print('k= ',i, 'mean rank: ', compute_IR_evaluation_scores(features_train_transformed, features_val_transformed, train_labels, val_labels)[0] )
# Out:
# <ipython-input-35-f74403f14492>:7: RuntimeWarning: invalid value encountered in double_scalars
#   manual_cosine_similarity = np.dot(v1, v2)  /(norm(v1) * norm(v2))
# <ipython-input-35-f74403f14492>:7: RuntimeWarning: invalid value encountered in double_scalars
#   manual_cosine_similarity = np.dot(v1, v2)  /(norm(v1) * norm(v2))
# <ipython-input-35-f74403f14492>:7: RuntimeWarning: invalid value encountered in double_scalars
#   manual_cosine_similarity = np.dot(v1, v2)  /(norm(v1) * norm(v2))
# <ipython-input-35-f74403f14492>:7: RuntimeWarning: invalid value encountered in double_scalars
#   manual_cosine_similarity = np.dot(v1, v2)  /(norm(v1) * norm(v2))
# <ipython-input-35-f74403f14492>:7: RuntimeWarning: invalid value encountered in double_scalars
#   manual_cosine_similarity = np.dot(v1, v2)  /(norm(v1) * norm(v2))
# <ipython-input-35-f74403f14492>:7: RuntimeWarning: invalid value encountered in double_scalars
#   manual_cosine_similarity = np.dot(v1, v2)  /(norm(v1) * norm(v2))
# <ipython-input-35-f74403f14492>:7: RuntimeWarning: invalid value encountered in double_scalars
#   manual_cosine_similarity = np.dot(v1, v2)  /(norm(v1) * norm(v2))
# <ipython-input-35-f74403f14492>:7: RuntimeWarning: invalid value encountered in double_scalars
#   manual_cosine_similarity = np.dot(v1, v2)  /(norm(v1) * norm(v2))
# <ipython-input-35-f74403f14492>:7: RuntimeWarning: invalid value encountered in double_scalars
#   manual_cosine_similarity = np.dot(v1, v2)  /(norm(v1) * norm(v2))
# <ipython-input-35-f74403f14492>:7: RuntimeWarning: invalid value encountered in double_scalars
#   manual_cosine_similarity = np.dot(v1, v2)  /(norm(v1) * norm(v2))
# <ipython-input-35-f74403f14492>:7: RuntimeWarning: invalid value encountered in double_scalars
#   manual_cosine_similarity = np.dot(v1, v2)  /(norm(v1) * norm(v2))
# <ipython-input-35-f74403f14492>:7: RuntimeWarning: invalid value encountered in double_scalars
#   manual_cosine_similarity = np.dot(v1, v2)  /(norm(v1) * norm(v2))
# <ipython-input-35-f74403f14492>:7: RuntimeWarning: invalid value encountered in double_scalars
#   manual_cosine_similarity = np.dot(v1, v2)  /(norm(v1) * norm(v2))
# <ipython-input-35-f74403f14492>:7: RuntimeWarning: invalid value encountered in double_scalars
#   manual_cosine_similarity = np.dot(v1, v2)  /(norm(v1) * norm(v2))
# <ipython-input-35-f74403f14492>:7: RuntimeWarning: invalid value encountered in double_scalars
#   manual_cosine_similarity = np.dot(v1, v2)  /(norm(v1) * norm(v2))
# <ipython-input-35-f74403f14492>:7: RuntimeWarning: invalid value encountered in double_scalars
#   manual_cosine_similarity = np.dot(v1, v2)  /(norm(v1) * norm(v2))
# mean rank 8.5
# mean cosine similarity nan
# 1 correct out of 16 / accuracy: 0.0625
# k=  50 mean rank:  8.5
# mean rank 8.5
# mean cosine similarity nan
# 1 correct out of 16 / accuracy: 0.0625
# k=  100 mean rank:  8.5
# mean rank 8.5
# mean cosine similarity nan
# 1 correct out of 16 / accuracy: 0.0625
# k=  150 mean rank:  8.5
# mean rank 8.625
# mean cosine similarity nan
# 1 correct out of 16 / accuracy: 0.0625
# k=  200 mean rank:  8.625
# mean rank 8.6875
# mean cosine similarity nan
# 1 correct out of 16 / accuracy: 0.0625
# k=  250 mean rank:  8.6875
# mean rank 8.6875
# mean cosine similarity nan
# 1 correct out of 16 / accuracy: 0.0625
# k=  300 mean rank:  8.6875
# mean rank 8.6875
# mean cosine similarity nan
# 1 correct out of 16 / accuracy: 0.0625
# k=  350 mean rank:  8.6875
# mean rank 8.6875
# mean cosine similarity nan
# 1 correct out of 16 / accuracy: 0.0625
# k=  400 mean rank:  8.6875
# mean rank 8.4375
# mean cosine similarity nan
# 1 correct out of 16 / accuracy: 0.0625
# k=  450 mean rank:  8.4375
# mean rank 8.625
# mean cosine similarity nan
# 0 correct out of 16 / accuracy: 0.0
# k=  500 mean rank:  8.625
# mean rank 7.8125
# mean cosine similarity nan
# 1 correct out of 16 / accuracy: 0.0625
# k=  550 mean rank:  7.8125
# mean rank 7.9375
# mean cosine similarity nan
# 1 correct out of 16 / accuracy: 0.0625
# k=  600 mean rank:  7.9375
# mean rank 8.0
# mean cosine similarity nan
# 1 correct out of 16 / accuracy: 0.0625
# k=  650 mean rank:  8.0
# mean rank 8.125
# mean cosine similarity nan
# 0 correct out of 16 / accuracy: 0.0
# k=  700 mean rank:  8.125
# mean rank 8.1875
# mean cosine similarity nan
# 0 correct out of 16 / accuracy: 0.0
# k=  750 mean rank:  8.1875
# mean rank 8.3125
# mean cosine similarity nan
# 0 correct out of 16 / accuracy: 0.0
# k=  800 mean rank:  8.3125
# mean rank 8.3125
# mean cosine similarity 0.011668797415934573
# 0 correct out of 16 / accuracy: 0.0
# k=  850 mean rank:  8.3125
# mean rank 7.6875
# mean cosine similarity 0.015849898435700064
# 1 correct out of 16 / accuracy: 0.0625
# k=  900 mean rank:  7.6875
# mean rank 7.875
# mean cosine similarity 0.015104855701350974
# 1 correct out of 16 / accuracy: 0.0625
# k=  950 mean rank:  7.875
# mean rank 8.0
# mean cosine similarity 0.017959946046203514
# 1 correct out of 16 / accuracy: 0.0625
# k=  1000 mean rank:  8.0
# mean rank 8.0
# mean cosine similarity 0.017385739776624713
# 1 correct out of 16 / accuracy: 0.0625
# k=  1050 mean rank:  8.0
# mean rank 8.125
# mean cosine similarity 0.01715152059587668
# 1 correct out of 16 / accuracy: 0.0625
# k=  1100 mean rank:  8.125
# mean rank 8.125
# mean cosine similarity 0.01674706235429592
# 1 correct out of 16 / accuracy: 0.0625
# k=  1150 mean rank:  8.125
# mean rank 8.1875
# mean cosine similarity 0.01652414596793559
# 1 correct out of 16 / accuracy: 0.0625
# k=  1200 mean rank:  8.1875
# mean rank 8.0625
# mean cosine similarity 0.021228755679447563
# 2 correct out of 16 / accuracy: 0.125
# k=  1250 mean rank:  8.0625
# mean rank 7.3125
# mean cosine similarity 0.02489862859459932
# 3 correct out of 16 / accuracy: 0.1875
# k=  1300 mean rank:  7.3125
# mean rank 6.875
# mean cosine similarity 0.027706333195129426
# 3 correct out of 16 / accuracy: 0.1875
# k=  1350 mean rank:  6.875
# mean rank 7.0
# mean cosine similarity 0.027315645537699766
# 3 correct out of 16 / accuracy: 0.1875
# k=  1400 mean rank:  7.0
# mean rank 7.0
# mean cosine similarity 0.026412965433480626
# 3 correct out of 16 / accuracy: 0.1875
# k=  1450 mean rank:  7.0
# mean rank 7.0625
# mean cosine similarity 0.025440828209503597
# 3 correct out of 16 / accuracy: 0.1875
# k=  1500 mean rank:  7.0625
# mean rank 7.25
# mean cosine similarity 0.0240919270914745
# 3 correct out of 16 / accuracy: 0.1875
# k=  1550 mean rank:  7.25
# mean rank 7.3125
# mean cosine similarity 0.02330185776944929
# 2 correct out of 16 / accuracy: 0.125
# k=  1600 mean rank:  7.3125
# mean rank 7.3125
# mean cosine similarity 0.02271866514730036
# 2 correct out of 16 / accuracy: 0.125
# k=  1650 mean rank:  7.3125
# mean rank 7.3125
# mean cosine similarity 0.022213433543539107
# 2 correct out of 16 / accuracy: 0.125
# k=  1700 mean rank:  7.3125
# mean rank 7.3125
# mean cosine similarity 0.02148332749895662
# 2 correct out of 16 / accuracy: 0.125
# k=  1750 mean rank:  7.3125
# mean rank 7.3125
# mean cosine similarity 0.021152210460316026
# 2 correct out of 16 / accuracy: 0.125
# k=  1800 mean rank:  7.3125
# mean rank 7.375
# mean cosine similarity 0.020587182393617377
# 2 correct out of 16 / accuracy: 0.125
# k=  1850 mean rank:  7.375
# mean rank 7.5
# mean cosine similarity 0.01991986405874723
# 2 correct out of 16 / accuracy: 0.125
# k=  1900 mean rank:  7.5
# mean rank 7.5
# mean cosine similarity 0.019346586267512393
# 2 correct out of 16 / accuracy: 0.125
# k=  1950 mean rank:  7.5
# mean rank 7.5
# mean cosine similarity 0.019140138754539678
# 2 correct out of 16 / accuracy: 0.125
# k=  2000 mean rank:  7.5
# mean rank 7.5625
# mean cosine similarity 0.0187935672648612
# 2 correct out of 16 / accuracy: 0.125
# k=  2050 mean rank:  7.5625
# mean rank 6.875
# mean cosine similarity 0.0230352555129783
# 3 correct out of 16 / accuracy: 0.1875
# k=  2100 mean rank:  6.875
# mean rank 6.0
# mean cosine similarity 0.02777270935936534
# 3 correct out of 16 / accuracy: 0.1875
# k=  2150 mean rank:  6.0
# mean rank 6.0
# mean cosine similarity 0.02731804044459194
# 3 correct out of 16 / accuracy: 0.1875
# k=  2200 mean rank:  6.0
# mean rank 5.9375
# mean cosine similarity 0.02836976450674983
# 3 correct out of 16 / accuracy: 0.1875
# k=  2250 mean rank:  5.9375
# mean rank 6.0625
# mean cosine similarity 0.028074954202084737
# 3 correct out of 16 / accuracy: 0.1875
# k=  2300 mean rank:  6.0625
# mean rank 6.0625
# mean cosine similarity 0.027758680405474318
# 3 correct out of 16 / accuracy: 0.1875
# k=  2350 mean rank:  6.0625
# mean rank 6.0625
# mean cosine similarity 0.027272986739782738
# 3 correct out of 16 / accuracy: 0.1875
# k=  2400 mean rank:  6.0625
# mean rank 6.0625
# mean cosine similarity 0.0287091719093278
# 3 correct out of 16 / accuracy: 0.1875
# k=  2450 mean rank:  6.0625
# mean rank 5.5625
# mean cosine similarity 0.03140306690096048
# 3 correct out of 16 / accuracy: 0.1875
# k=  2500 mean rank:  5.5625
# mean rank 5.8125
# mean cosine similarity 0.03087874659503578
# 3 correct out of 16 / accuracy: 0.1875
# k=  2550 mean rank:  5.8125
# mean rank 5.75
# mean cosine similarity 0.030346112339494895
# 3 correct out of 16 / accuracy: 0.1875
# k=  2600 mean rank:  5.75
# mean rank 5.875
# mean cosine similarity 0.029967790872307
# 2 correct out of 16 / accuracy: 0.125
# k=  2650 mean rank:  5.875
# mean rank 5.9375
# mean cosine similarity 0.02956130211789288
# 1 correct out of 16 / accuracy: 0.0625
# k=  2700 mean rank:  5.9375
# mean rank 6.0
# mean cosine similarity 0.028202229003112447
# 1 correct out of 16 / accuracy: 0.0625
# k=  2750 mean rank:  6.0
# mean rank 6.125
# mean cosine similarity 0.027684088696644904
# 1 correct out of 16 / accuracy: 0.0625
# k=  2800 mean rank:  6.125
# mean rank 6.125
# mean cosine similarity 0.027386142418273317
# 2 correct out of 16 / accuracy: 0.125
# k=  2850 mean rank:  6.125
# mean rank 6.0625
# mean cosine similarity 0.02862079840527011
# 2 correct out of 16 / accuracy: 0.125
# k=  2900 mean rank:  6.0625
# mean rank 6.125
# mean cosine similarity 0.02813591151744388
# 2 correct out of 16 / accuracy: 0.125
# k=  2950 mean rank:  6.125
# mean rank 5.3125
# mean cosine similarity 0.029860907245500175
# 3 correct out of 16 / accuracy: 0.1875
# k=  3000 mean rank:  5.3125
# mean rank 5.3125
# mean cosine similarity 0.029632935234289247
# 3 correct out of 16 / accuracy: 0.1875
# k=  3050 mean rank:  5.3125
# mean rank 5.375
# mean cosine similarity 0.02926733533310517
# 3 correct out of 16 / accuracy: 0.1875
# k=  3100 mean rank:  5.375
# mean rank 5.3125
# mean cosine similarity 0.028729772261405877
# 3 correct out of 16 / accuracy: 0.1875
# k=  3150 mean rank:  5.3125
# mean rank 5.1875
# mean cosine similarity 0.029576130293389874
# 3 correct out of 16 / accuracy: 0.1875
# k=  3200 mean rank:  5.1875
# mean rank 5.25
# mean cosine similarity 0.029069972927443524
# 3 correct out of 16 / accuracy: 0.1875
# k=  3250 mean rank:  5.25
# mean rank 5.3125
# mean cosine similarity 0.03187545779335614
# 3 correct out of 16 / accuracy: 0.1875
# k=  3300 mean rank:  5.3125
# mean rank 5.1875
# mean cosine similarity 0.03273730359304242
# 3 correct out of 16 / accuracy: 0.1875
# k=  3350 mean rank:  5.1875
# mean rank 4.5
# mean cosine similarity 0.035915176905083
# 4 correct out of 16 / accuracy: 0.25
# k=  3400 mean rank:  4.5
# mean rank 3.9375
# mean cosine similarity 0.03924083947276983
# 5 correct out of 16 / accuracy: 0.3125
# k=  3450 mean rank:  3.9375
# mean rank 3.4375
# mean cosine similarity 0.040766000955472906
# 5 correct out of 16 / accuracy: 0.3125
# k=  3500 mean rank:  3.4375
# mean rank 3.0
# mean cosine similarity 0.04425830683521815
# 7 correct out of 16 / accuracy: 0.4375
# k=  3550 mean rank:  3.0
# mean rank 3.0625
# mean cosine similarity 0.04405144765808073
# 6 correct out of 16 / accuracy: 0.375
# k=  3600 mean rank:  3.0625
# mean rank 3.4375
# mean cosine similarity 0.04459786365402421
# 6 correct out of 16 / accuracy: 0.375
# k=  3650 mean rank:  3.4375
# mean rank 3.6875
# mean cosine similarity 0.04418302380704599
# 6 correct out of 16 / accuracy: 0.375
# k=  3700 mean rank:  3.6875
# mean rank 3.4375
# mean cosine similarity 0.04578383612414505
# 8 correct out of 16 / accuracy: 0.5
# k=  3750 mean rank:  3.4375
# mean rank 3.625
# mean cosine similarity 0.046156705994561176
# 7 correct out of 16 / accuracy: 0.4375
# k=  3800 mean rank:  3.625
# mean rank 3.5625
# mean cosine similarity 0.0451425126514768
# 7 correct out of 16 / accuracy: 0.4375
# k=  3850 mean rank:  3.5625
# mean rank 3.5
# mean cosine similarity 0.04591766268855542
# 7 correct out of 16 / accuracy: 0.4375
# k=  3900 mean rank:  3.5
# mean rank 3.625
# mean cosine similarity 0.04718969868165333
# 7 correct out of 16 / accuracy: 0.4375
# k=  3950 mean rank:  3.625
# mean rank 3.8125
# mean cosine similarity 0.047914271550542474
# 7 correct out of 16 / accuracy: 0.4375
# k=  4000 mean rank:  3.8125
# mean rank 3.875
# mean cosine similarity 0.04901977601274049
# 8 correct out of 16 / accuracy: 0.5
# k=  4050 mean rank:  3.875
# mean rank 3.5625
# mean cosine similarity 0.05120726582985149
# 8 correct out of 16 / accuracy: 0.5
# k=  4100 mean rank:  3.5625
# mean rank 3.5
# mean cosine similarity 0.051816373863426336
# 7 correct out of 16 / accuracy: 0.4375
# k=  4150 mean rank:  3.5
# mean rank 3.625
# mean cosine similarity 0.051230858316689304
# 7 correct out of 16 / accuracy: 0.4375
# k=  4200 mean rank:  3.625
# mean rank 3.8125
# mean cosine similarity 0.05419249959669474
# 9 correct out of 16 / accuracy: 0.5625
# k=  4250 mean rank:  3.8125
# mean rank 3.625
# mean cosine similarity 0.056675790420972684
# 7 correct out of 16 / accuracy: 0.4375
# k=  4300 mean rank:  3.625
# mean rank 3.8125
# mean cosine similarity 0.06002983164043954
# 7 correct out of 16 / accuracy: 0.4375
# k=  4350 mean rank:  3.8125
# mean rank 3.875
# mean cosine similarity 0.06227024631185807
# 9 correct out of 16 / accuracy: 0.5625
# k=  4400 mean rank:  3.875
# mean rank 3.9375
# mean cosine similarity 0.06457203600242756
# 9 correct out of 16 / accuracy: 0.5625
# k=  4450 mean rank:  3.9375
# mean rank 3.25
# mean cosine similarity 0.0686707424953649
# 10 correct out of 16 / accuracy: 0.625
# k=  4500 mean rank:  3.25
# mean rank 2.875
# mean cosine similarity 0.07433651066384817
# 10 correct out of 16 / accuracy: 0.625
# k=  4550 mean rank:  2.875
# mean rank 2.5
# mean cosine similarity 0.07819870881563934
# 10 correct out of 16 / accuracy: 0.625
# k=  4600 mean rank:  2.5
# mean rank 1.9375
# mean cosine similarity 0.08237652386622507
# 12 correct out of 16 / accuracy: 0.75
# k=  4650 mean rank:  1.9375
# mean rank 1.875
# mean cosine similarity 0.08519282007097133
# 12 correct out of 16 / accuracy: 0.75
# k=  4700 mean rank:  1.875
# mean rank 1.9375
# mean cosine similarity 0.08666947133957321
# 13 correct out of 16 / accuracy: 0.8125
# k=  4750 mean rank:  1.9375
# mean rank 2.0
# mean cosine similarity 0.08908403924449007
# 11 correct out of 16 / accuracy: 0.6875
# k=  4800 mean rank:  2.0
# mean rank 2.0
# mean cosine similarity 0.09251457504232316
# 11 correct out of 16 / accuracy: 0.6875
# k=  4850 mean rank:  2.0
# mean rank 1.9375
# mean cosine similarity 0.09798326755487187
# 11 correct out of 16 / accuracy: 0.6875
# k=  4900 mean rank:  1.9375
# mean rank 1.875
# mean cosine similarity 0.10238582408604519
# 12 correct out of 16 / accuracy: 0.75
# k=  4950 mean rank:  1.875
# mean rank 1.75
# mean cosine similarity 0.10920701959483188
# 11 correct out of 16 / accuracy: 0.6875
# k=  5000 mean rank:  1.75
# mean rank 1.875
# mean cosine similarity 0.11550940799221647
# 13 correct out of 16 / accuracy: 0.8125
# k=  5050 mean rank:  1.875
# mean rank 1.6875
# mean cosine similarity 0.1271974409024287
# 13 correct out of 16 / accuracy: 0.8125
# k=  5100 mean rank:  1.6875
# mean rank 1.8125
# mean cosine similarity 0.13472643294117984
# 12 correct out of 16 / accuracy: 0.75
# k=  5150 mean rank:  1.8125
# mean rank 2.4375
# mean cosine similarity 0.14448074893710228
# 11 correct out of 16 / accuracy: 0.6875
# k=  5200 mean rank:  2.4375
# mean rank 2.125
# mean cosine similarity 0.15631493918519876
# 12 correct out of 16 / accuracy: 0.75
# k=  5250 mean rank:  2.125
# mean rank 2.125
# mean cosine similarity 0.1773528044383016
# 10 correct out of 16 / accuracy: 0.625
# k=  5300 mean rank:  2.125
# mean rank 2.4375
# mean cosine similarity 0.2098214696119876
# 11 correct out of 16 / accuracy: 0.6875
# k=  5350 mean rank:  2.4375
# mean rank 2.375
# mean cosine similarity 0.25358428808924716
# 11 correct out of 16 / accuracy: 0.6875
# k=  5400 mean rank:  2.375

# %%
#the best solution for Q2
from sklearn.feature_selection import SelectKBest, chi2
selector =  SelectKBest(chi2,k=5100)
training_feature_matrix2 = selector.fit(training_feature_matrix, train_labels)
features_train_transformed = selector.transform(training_feature_matrix)
features_val_transformed = selector.transform(val_feature_matrix)
mean_rank, mean_cosine_simliarity, acc, df0 = compute_IR_evaluation_scores(features_train_transformed, features_val_transformed, train_labels, val_labels)
# Out:
# mean rank 1.6875
# mean cosine similarity 0.1271974409024287
# 13 correct out of 16 / accuracy: 0.8125

# %% [markdown]
# # Task 3. Add dialogue context data and features
# Adjust `create_character_document_from_dataframe` and the other functions so the data incorporates the context of the line spoken by the characters in terms of the lines spoken by other characters in the same scene (immediately before and after).

# %% [markdown]
# ### Answer: to avoid confusion, please run all the codes from here as the beginning for Q3:
#
# For this question, the main changes have been made in the function - create_character_document_from_dataframe2() to include one line before and after within the same scene. And I have made the 'character_line_count' dictionary count in a way that the <before line + current line + after line>'s count incrementing by 1 rather than 3 each time. I believe this makes more sense as we considering the surrounding texts as extra contents / features to the current lines to be analyzed.
#
# However, the result is not very good. It achieved a mean rank of 2.0625, which is not as good as Task2's best result (Task2 mean rank - 1.6875).

# %%
import string
import re
import numpy as np
from numpy.linalg import norm
import pandas as pd
from collections import Counter, OrderedDict

import seaborn as sns
import matplotlib.pyplot as plt

import nltk

from sklearn.feature_extraction import DictVectorizer

# %matplotlib inline
pd.options.display.max_colwidth=500

# %%
# Load in training data and display in pandas dataframe
train_path='training.csv'
all_train_data = pd.read_csv(train_path,  delimiter="\t", skip_blank_lines = True)
test_path ='test.csv'
test_data = pd.read_csv(test_path,  delimiter="\t", skip_blank_lines = True)

# Inspect
all_train_data.head()
# Out:
#    Episode  Scene                   Scene_info Character_name  \
# 0     1350      1  DESERTED CAR PARK EXT NIGHT        SHIRLEY
# 1     1350      1  DESERTED CAR PARK EXT NIGHT          OTHER
# 2     1350      2                R&R INT NIGHT           JACK
# 3     1350      2                R&R INT NIGHT         RONNIE
# 4     1350      2                R&R INT NIGHT           JACK
#
#                                                                                                     Line  \
# 0                                     Look at ya, not a mark on ya. And you think you're an unlucky man.
# 1                                                                                               Shirl...
# 2                                               Oi. Where have you been? Huh? What were the texts about?
# 3                                                Nothing. Nothing. I'll be with you in two minutes yeah?
# 4  Well I've got mates here I wanted to have a chat with them, instead I've been serving behind the bar.
#
#    Gender
# 0  FEMALE
# 1    MALE
# 2    MALE
# 3  FEMALE
# 4    MALE

# %%
#Inspect
test_data.head()
# Out:
#    Episode  Scene                   Scene_info Character_name  \
# 0     1350      7  DESERTED CAR PARK EXT NIGHT        SHIRLEY
# 1     1350      7  DESERTED CAR PARK EXT NIGHT          OTHER
# 2     1350      7  DESERTED CAR PARK EXT NIGHT        SHIRLEY
# 3     1350      7  DESERTED CAR PARK EXT NIGHT          OTHER
# 4     1350      7  DESERTED CAR PARK EXT NIGHT        SHIRLEY
#
#                                                                                                                                                                                    Line  \
# 0  You'll be alright Kevin. They're gonna cut you out. It's going to be alright. Come on, just talk to me. Just, just talk to me. Call me names- let me know you're still here with me.
# 1                                                                                                                                           ...I've got pins and needles in my fingers.
# 2                                                                                                                                                                      That's the cold.
# 3                                                                                                                                                         Yeah. It's all shutting down.
# 4                                                                                                                                                                   It's just the cold.
#
#    Gender
# 0  FEMALE
# 1    MALE
# 2  FEMALE
# 3    MALE
# 4  FEMALE

# %%
# Split into training and test data for heldout validation with random samples of 9:1 train/heldout split
from random import shuffle, seed

seed(0) # set a seed for reproducibility so same split is used each time

epsiode_scene_column = all_train_data.Episode.astype(str) + "-" + all_train_data.Scene.astype(str)
all_train_data['episode_scene'] = epsiode_scene_column
episode_scenes = sorted(list(set([x for x in epsiode_scene_column.values]))) # set function is random, need to sort!

shuffle(episode_scenes)

print(len(episode_scenes))
episode_split = int(0.9*len(episode_scenes))
training_ep_scenes = episode_scenes[:episode_split]
test_ep_scenes = episode_scenes[episode_split:]
print(len(training_ep_scenes), len(test_ep_scenes))

def train_or_heldout_eps(val):
    if val in training_ep_scenes:
        return "training"
    return "heldout"

all_train_data['train_heldout'] = all_train_data['episode_scene'].apply(train_or_heldout_eps)
# Out:
# 1394
# 1254 140

# %%
print('Raw Data: ',np.shape(all_train_data))
train_data = all_train_data[all_train_data['train_heldout']=='training']
val_data = all_train_data[all_train_data['train_heldout']=='heldout']
print('Train set: ',np.shape(train_data))
print('Validation set: ',np.shape(val_data))
# Out:
# Raw Data:  (15319, 8)
# Train set:  (13638, 8)
# Validation set:  (1681, 8)

# %%
train_data.head()
# Out:
#    Episode  Scene                   Scene_info Character_name  \
# 0     1350      1  DESERTED CAR PARK EXT NIGHT        SHIRLEY
# 1     1350      1  DESERTED CAR PARK EXT NIGHT          OTHER
# 2     1350      2                R&R INT NIGHT           JACK
# 3     1350      2                R&R INT NIGHT         RONNIE
# 4     1350      2                R&R INT NIGHT           JACK
#
#                                                                                                     Line  \
# 0                                     Look at ya, not a mark on ya. And you think you're an unlucky man.
# 1                                                                                               Shirl...
# 2                                               Oi. Where have you been? Huh? What were the texts about?
# 3                                                Nothing. Nothing. I'll be with you in two minutes yeah?
# 4  Well I've got mates here I wanted to have a chat with them, instead I've been serving behind the bar.
#
#    Gender episode_scene train_heldout
# 0  FEMALE        1350-1      training
# 1    MALE        1350-1      training
# 2    MALE        1350-2      training
# 3  FEMALE        1350-2      training
# 4    MALE        1350-2      training

# %%
val_data.head()
# Out:
#     Episode  Scene                  Scene_info Character_name  \
# 56     1350     18  BRANNINGS' HOUSE INT NIGHT          TANYA
# 57     1350     18  BRANNINGS' HOUSE INT NIGHT            MAX
# 58     1350     18  BRANNINGS' HOUSE INT NIGHT           SEAN
# 59     1350     18  BRANNINGS' HOUSE INT NIGHT          TANYA
# 60     1350     18  BRANNINGS' HOUSE INT NIGHT            MAX
#
#                                                                                                                                                                                                           Line  \
# 56                                                                                                                                                                                                 Who's that?
# 57                                                                                                                                              Tanya! Tanya it's me. I wanna give Oscar a New Year kiss. Tan?
# 58                                                                                                                                                                                    Right. I'll have a word.
# 59                                                                                                                    No no no leave it, leave it. He ain't got a key. He'll go away. Do you want some crisps?
# 60  Who, who you got in there, Tan? Tan, I've got a right to know who my kids are being exposed to. I bet you ain't got anyone have ya? You're just sitting there with a bottle of wine all on your Jack, Tan?
#
#     Gender episode_scene train_heldout
# 56  FEMALE       1350-18       heldout
# 57    MALE       1350-18       heldout
# 58    MALE       1350-18       heldout
# 59  FEMALE       1350-18       heldout
# 60    MALE       1350-18       heldout

# %% [markdown]
# ### Main changes for Q3 have been made here below in the create_character_document_from_dataframe2() function to include one line before and after within the same scene. And I have made the 'character_line_count' dictionary count in a way that the <before line + current line + after line>'s count incrementing by 1 rather than 3 each time.

# %%
#updated version for Task3
#code modified to add one line before and after for all the documents if they are within the same episode-scene
# Create one document per character
def create_character_document_from_dataframe2(df, max_line_count):

    character_docs = {}
    character_line_count = {}
    character_gender = {}
    for line, name, gender, i in zip(df.Line, df.Character_name, df.Gender, range(len(df))):
       
        if not name in character_docs.keys():
            character_docs[name] = ""
            character_line_count[name] = 0
        if character_line_count[name]==max_line_count:
            continue
        
        # add the line before that if they are within the same scene
        if i>0:
            if df.iloc[i,6] == df.iloc[i-1,6]: #one line before
                character_docs[name] += str(df.iloc[i-1,4]) + "_BFEOL_ "
                #character_line_count[name]+=1
                #print(character_docs)
                #print(character_line_count)
                
        if character_line_count[name]==max_line_count:
            continue
        # add the current line
        character_docs[name] += str(df.iloc[i,4])   + " _EOL_ "
        character_line_count[name]+=1
        #print(character_docs)
        #print(character_line_count)    
        if character_line_count[name]==max_line_count:
            continue
        
        # add the line after that if they are within the same scene
        if len(df)-i-1>0:
            if df.iloc[i,6] == df.iloc[i+1,6]: #one line after
                character_docs[name] += str(df.iloc[i+1,4]) + "_AFTEOL_ "
                #character_line_count[name]+=1
                #print(character_docs)
                #print(character_line_count)

        
    #obtain name gender mapping info for Q2
    for name, gender in zip(df.Character_name, df.Gender):
        if name != "OTHER": #as other has diff gender, do not extract its gender
            character_gender[name] =str(gender)
                
    print("name-gender mapping: ", character_gender)
    print("\nlines per character", character_line_count)
    return character_docs

# %%
# print out the number of words each character has in the training set
# only use the first 360 lines of each character
train_character_docs = create_character_document_from_dataframe2(train_data, max_line_count=360)
print('Num. Characters: ',len(train_character_docs.keys()),"\n")
total_words = 0
for name in train_character_docs.keys():
    print(name, 'Number of Words: ',len(train_character_docs[name].split()))
    total_words += len(train_character_docs[name].split())
print("total words", total_words)
# Out:
# name-gender mapping:  {'SHIRLEY': 'FEMALE', 'JACK': 'MALE', 'RONNIE': 'FEMALE', 'TANYA': 'FEMALE', 'SEAN': 'MALE', 'ROXY': 'FEMALE', 'HEATHER': 'FEMALE', 'MAX': 'MALE', 'IAN': 'MALE', 'JANE': 'FEMALE', 'STACEY': 'FEMALE', 'PHIL': 'MALE', 'MINTY': 'MALE', 'CHRISTIAN': 'MALE', 'CLARE': 'FEMALE'}
#
# lines per character {'SHIRLEY': 360, 'OTHER': 360, 'JACK': 360, 'RONNIE': 360, 'TANYA': 360, 'SEAN': 360, 'ROXY': 360, 'HEATHER': 360, 'MAX': 360, 'IAN': 360, 'JANE': 360, 'STACEY': 360, 'PHIL': 360, 'MINTY': 360, 'CHRISTIAN': 342, 'CLARE': 352}
# Num. Characters:  16
#
# SHIRLEY Number of Words:  9938
# OTHER Number of Words:  8215
# JACK Number of Words:  10135
# RONNIE Number of Words:  10301
# TANYA Number of Words:  9660
# SEAN Number of Words:  9624
# ROXY Number of Words:  10139
# HEATHER Number of Words:  10798
# MAX Number of Words:  10225
# IAN Number of Words:  10647
# JANE Number of Words:  10083
# STACEY Number of Words:  10200
# PHIL Number of Words:  10969
# MINTY Number of Words:  11019
# CHRISTIAN Number of Words:  9818
# CLARE Number of Words:  10223
# total words 161994

# %%
# !pip3 install afinn
from afinn import Afinn
# Out:
# Requirement already satisfied: afinn in c:\users\dandi\anaconda3\lib\site-packages (0.1)

# %%
#Q2 version3 updated tokenize with POS tags and sentiment score generated
#what it does to the text: sentiment score generated, pos tag generated, lower case, 
#remove punctuation, remove stop words, word stemming

#difference made from Q1: sentiment score added

# import and download relative libraries for tokenize
from nltk.corpus import stopwords
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.tokenize import sent_tokenize, word_tokenize
nltk.download('punkt')
from nltk.stem import PorterStemmer
ps = PorterStemmer()
import nltk
nltk.download('averaged_perceptron_tagger')



def pre_process1(character_text):


    
    wordlist = []
    poslist= []

    #change to lower case
    character_text = character_text.lower()
        
    #remove '_eol_'
    #character_text = character_text.replace("_eol_ ","")
    
    #generate pos tags
    tokens = word_tokenize(character_text)
    wordpos = nltk.pos_tag(tokens)
    
    #remove punctuation
    symbols = "!#$%&()*@+-.,/:;<=>?[\]^`{|}~\n"
    j=0
    for i in range(len(wordpos)):
        for symbol in symbols:
            if wordpos[i-j][0] == symbol:    
                del wordpos[i-j]
                j += 1
              
        
    #remove stop words
    stops = stopwords.words('english')
    k=0
    for i in range(len(wordpos)):
        for stop in stops:
            if wordpos[i-k][0] == stop:    
                del wordpos[i-k]
                k += 1

    for i in range(len(wordpos)):
        word = wordpos[i][0]
        pos = wordpos[i][1]
        wordlist.append(word)
        poslist.append(pos)
 

    #stemming
    wordlist2 = []
    for w in wordlist:
        wordlist2.append(ps.stem(w))
    

    return wordlist2, poslist
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\dandi\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\dandi\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\dandi\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
# create list of pairs of (character name, pre-processed character) 
training_corpus = [(name, pre_process1(doc)[0]) for name, doc in sorted(train_character_docs.items())]
train_labels = [name for name, doc in training_corpus]

# %%
# create list of pairs of (character name, pre-processed pos tags)
training_POS = [(name, pre_process1(doc)[1]) for name, doc in sorted(train_character_docs.items())]

# %%
#training_corpus

# %%
#modified v3

import nltk
nltk.download('averaged_perceptron_tagger')
# !pip3 install afinn
from afinn import Afinn

def to_feature_vector_dictionary2(character_doc, tag, name):

    wordlist1 = [] #list store previous bigram

    senti_list = [] #list store sentiment scores for each token


    #counts = Counter(character_doc)  # for now a simple count
    #counts = dict(counts)
    counts = {}
    
    #add POS tag features
    #pos = Counter(tag)
    #pos = dict(pos)
    #counts.update(pos)
    
    #sentiment score analysis for each word
    afinn = Afinn()
    for j in character_doc:
        word_senti =  str(afinn.score(j))
        senti_list.append(word_senti)
    
    #experiment1 target word and its tag
    '''for i in range(len(character_doc)):
        word = character_doc[i] +'@'+ tag[i]
        wordlist1.append(word)

    word_counts = Counter(wordlist1)
    word_counts = dict(word_counts)
    for a in word_counts:
        counts[a] = 0
        counts[a] +=1'''
    
    #experiment2 target word and one prev word&tag
    '''for i in range(len(character_doc)):
        if i>0:
            word = character_doc[i-1] +'@'+ tag[i-1]+'_'+character_doc[i]+'@'+tag[i]
            wordlist1.append(word)

    word_counts = Counter(wordlist1)
    word_counts = dict(word_counts)
    for a in word_counts:
        counts[a] = 0
        counts[a] +=1'''
        
    #experiment 3 target word and one after word&tag
    '''for i in range(len(character_doc)):        
            if len(character_doc)-i>1:
                word = character_doc[i] +'@'+tag[i]+'_' + character_doc[i+1]+'@'+tag[i+1]    
            wordlist1.append(word)

    word_counts = Counter(wordlist1)
    word_counts = dict(word_counts)
    for a in word_counts:
        counts[a] = 0
        counts[a] +=1'''
        
    #experiment4 target and one after word
    '''for i in range(len(character_doc)):        
            if len(character_doc)-i>1:
                word = character_doc[i] +'_' + character_doc[i+1]    
            wordlist1.append(word)

    word_counts = Counter(wordlist1)
    word_counts = dict(word_counts)
    for a in word_counts:
        counts[a] = 0
        counts[a] +=1'''
    
    #experiment 5 target and one prev word
    '''for i in range(len(character_doc)):
        if i>0:
            word = character_doc[i-1] +'_'+character_doc[i]
            wordlist1.append(word)

    word_counts = Counter(wordlist1)
    word_counts = dict(word_counts)
    for a in word_counts:
        counts[a] = 0
        counts[a] +=1'''
    
    #experiment 6 target and one prev word and sentiment score
    '''for i in range(len(character_doc)):
        if i>0:
            word = character_doc[i-1] +'@'+ senti_list[i-1]+'_'+character_doc[i]+'@'+senti_list[i]
            wordlist1.append(word)

    word_counts = Counter(wordlist1)
    word_counts = dict(word_counts)
    for a in word_counts:
        counts[a] = 0
        counts[a] +=1'''
        
    #experiment 7 target word, tag and separated counter for gender i.e add another key and value - gender:1 for male
    for i in range(len(character_doc)):
        word = character_doc[i] +'@'+ tag[i]
        wordlist1.append(word)

    word_counts = Counter(wordlist1)
    word_counts = dict(word_counts)
    for a in word_counts:
        counts[a] = 0
        counts[a] +=1  

    
    #add gender feature, male=1, female=0
    #gender = 0
    #genders ={'SHIRLEY': 'FEMALE', 'JACK': 'MALE', 'RONNIE': 'FEMALE', 'TANYA': 'FEMALE', 'SEAN': 'MALE', 'ROXY': 'FEMALE', 'HEATHER': 'FEMALE', 'MAX': 'MALE', 'IAN': 'MALE', 'JANE': 'FEMALE', 'STACEY': 'FEMALE', 'PHIL': 'MALE', 'MINTY': 'MALE', 'CHRISTIAN': 'MALE', 'CLARE': 'FEMALE'}

    #for item in genders:
        #if name == item:
            #gender = genders[name]
            #if gender == "MALE":
                #gender =1
            #else: gender =0
    #counts.update({"Gender": gender})
    
    return counts
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\dandi\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# Requirement already satisfied: afinn in c:\users\dandi\anaconda3\lib\site-packages (0.1)

# %%
#updated version3
# changes made from original version: tag and name are parsed to 
#to_feature_vector_dictionary2()

corpusVectorizer = DictVectorizer()   # corpusVectorizor which will just produce sparse vectors from feature dicts

def create_document_matrix_from_corpus2(corpus,tag, fitting=False):
    """Method which fits different vectorizers
    on data and returns a matrix.
    
    Currently just does simple conversion to matrix by vectorizing the dictionary. Improve this for Q3.
    
    ::corpus:: a list of (class_label, document) pairs.
    ::fitting:: a boolean indicating whether to fit/train the vectorizers (should be true on training data)
    """
    
    # uses the global variable of the corpus Vectorizer to improve things
    if fitting:
        corpusVectorizer.fit([to_feature_vector_dictionary2(a[1],b[1],a[0]) for a, b in zip(corpus,tag)])

    doc_feature_matrix = corpusVectorizer.transform([to_feature_vector_dictionary2(a[1],b[1],a[0]) for a, b, in zip(corpus,tag)])
    
    #training_feature_matrix[0].toarray()
    return doc_feature_matrix

training_feature_matrix = create_document_matrix_from_corpus2(training_corpus, training_POS, fitting=True)

# %%
training_feature_matrix
# Out:
# <16x10504 sparse matrix of type '<class 'numpy.float64'>'
# 	with 28239 stored elements in Compressed Sparse Row format>

# %%
# get the validation data- only 40 lines used for each character
val_character_docs = create_character_document_from_dataframe(val_data, max_line_count=40)
print('Num. Characters: ',len(val_character_docs.keys()),"\n")
total_words = 0
for name in val_character_docs.keys():
    print(name, 'Num of Words: ',len(val_character_docs[name].split()))
    total_words += len(val_character_docs[name].split())
print("total words", total_words)

# create list of pairs of (character name, pre-processed character) 
val_corpus = [(name, pre_process1(doc)[0]) for name, doc in sorted(val_character_docs.items())]
val_labels = [name for name, doc in val_corpus]
# create list of pairs of (character name, POS tags) 
val_POS = [(name, pre_process1(doc)[1]) for name, doc in sorted(val_character_docs.items())]
# create list of pairs of (character name, sentiment score) 
#val_senti = [(name, pre_process1(doc)[2]) for name, doc in sorted(val_character_docs.items())]
# Out:
# name-gender mapping:  {'TANYA': 'FEMALE', 'MAX': 'MALE', 'SEAN': 'MALE', 'SHIRLEY': 'FEMALE', 'STACEY': 'FEMALE', 'RONNIE': 'FEMALE', 'JACK': 'MALE', 'PHIL': 'MALE', 'IAN': 'MALE', 'JANE': 'FEMALE', 'ROXY': 'FEMALE', 'HEATHER': 'FEMALE', 'MINTY': 'MALE', 'CHRISTIAN': 'MALE', 'CLARE': 'FEMALE'}
#
# lines per character {'TANYA': 40, 'MAX': 40, 'SEAN': 35, 'SHIRLEY': 40, 'OTHER': 40, 'STACEY': 40, 'RONNIE': 40, 'JACK': 40, 'PHIL': 40, 'IAN': 40, 'JANE': 40, 'ROXY': 40, 'HEATHER': 40, 'MINTY': 40, 'CHRISTIAN': 40, 'CLARE': 40}
# Num. Characters:  16
#
# TANYA Num of Words:  438
# MAX Num of Words:  737
# SEAN Num of Words:  366
# SHIRLEY Num of Words:  329
# OTHER Num of Words:  357
# STACEY Num of Words:  412
# RONNIE Num of Words:  464
# JACK Num of Words:  351
# PHIL Num of Words:  475
# IAN Num of Words:  508
# JANE Num of Words:  458
# ROXY Num of Words:  392
# HEATHER Num of Words:  411
# MINTY Num of Words:  470
# CHRISTIAN Num of Words:  489
# CLARE Num of Words:  405
# total words 7062

# %%
# Just transform the val_feature_matrix, don't fit
val_feature_matrix = create_document_matrix_from_corpus2(val_corpus,val_POS, fitting=False)

# %%
val_feature_matrix
# Out:
# <16x10504 sparse matrix of type '<class 'numpy.float64'>'
# 	with 2354 stored elements in Compressed Sparse Row format>

# %%
def compute_cosine_similarity(v1, v2):
    """Takes a pair of vectors v1 and v2 (1-d arrays e.g. [0, 0.5, 0.5])
    returns the cosine similarity between the vectors
    """
    
    # compute cosine similarity manually
    manual_cosine_similarity = np.dot(v1, v2)  /(norm(v1) * norm(v2))
    
    return manual_cosine_similarity

# %%
def compute_IR_evaluation_scores(train_feature_matrix, test_feature_matrix, train_labels, test_labels):
    """
    Computes an information retrieval based on training data feature matrix and test data feature matrix
    returns 4-tuple:
    ::mean_rank:: mean of the ranking of the target document in terms of similarity to the query/test document
    1 is the best possible score.
    ::mean_cosine_similarity:: mean cosine similarity score for the target document vs. the test document of the same class
    ::accuracy:: proportion of test documents correctly classified
    ::df:: a data frame with all the similarity measures of the test documents vs. train documents
    
    params:
    ::train_feature_matrix:: a numpy matrix N x M shape where N = number of characters M = number of features
    ::test_feature_matrix::  a numpy matrix N x M shape where N = number of characters M = number of features
    ::train_labels:: a list of character names for the training data in order consistent with train_feature_matrix
    ::test_labels:: a list of character names for the test data in order consistent with test_feature_matrix
    """
    rankings = []
    all_cosine_similarities = []
    pairwise_cosine_similarity = []
    pairs = []
    correct = 0
    for i, target in enumerate(test_labels):
        # compare the left out character against the mean
        idx = i 
        fm_1 = test_feature_matrix.toarray()[idx]
        all_sims = {}
        # print("target:", target)
        for j, other in enumerate(train_labels):
            fm_2 = train_feature_matrix.toarray()[j]
            manual_cosine_similarity = compute_cosine_similarity(fm_1, fm_2)
            pairs.append((target, other))
            pairwise_cosine_similarity.append(manual_cosine_similarity)
            if other == target:
                all_cosine_similarities.append(manual_cosine_similarity)
            all_sims[other] = manual_cosine_similarity

            # print(target, other, manual_cosine_similarity)
        sorted_similarities = sorted(all_sims.items(),key=lambda x:x[1],reverse=True)
        # print(sorted_similarities)
        ranking = {key[0]: rank for rank, key in enumerate(sorted_similarities, 1)}
        # print("Ranking for target", ranking[target])
        if ranking[target] == 1:
            correct += 1
        rankings.append(ranking[target])
        # print("*****")
    mean_rank = np.mean(rankings)
    mean_cosine_similarity = np.mean(all_cosine_similarities)
    accuracy = correct/len(test_labels)
    print("mean rank", np.mean(rankings))
    print("mean cosine similarity", mean_cosine_similarity)
    print(correct, "correct out of", len(test_labels), "/ accuracy:", accuracy )
    
    # get a dafaframe showing all the similarity scores of training vs test docs
    df = pd.DataFrame({'doc1': [x[0] for x in pairs], 'doc2': [x[1] for x in pairs],
                       'similarity': pairwise_cosine_similarity})

    # display characters which are most similar and least similar
    df.loc[[df.similarity.values.argmax(), df.similarity.values.argmin()]]
    return (mean_rank, mean_cosine_similarity, accuracy, df)

# %%
def plot_heat_map_similarity(df):
    """Takes a dataframe with header 'doc1, doc2, similarity'
    Plots a heatmap based on the similarity scores.
    """
    test_labels =  sorted(list(set(df.sort_values(['doc1'])['doc1'])))
    # add padding 1.0 values to either side
    cm = [[1.0,] * (len(test_labels)+2)]
    for target in test_labels:
        new_row = [1.0]
        for x in df.sort_values(['doc1', 'doc2'])[df['doc1']==target]['similarity']:
            new_row.append(x)
        new_row.append(1.0)
        cm.append(new_row)
    cm.append([1.0,] * (len(test_labels)+2))
    #print(cm)
    labels = [""] + test_labels + [""]
    fig = plt.figure(figsize=(20,20))
    ax = fig.add_subplot(111)
    cax = ax.matshow(cm)
    plt.title('Similarity matrix between documents as vectors')
    fig.colorbar(cax)
    ax.set_xticks(np.arange(len(labels)))
    ax.set_yticks(np.arange(len(labels)))
    ax.set_xticklabels( labels, rotation=45)
    ax.set_yticklabels( labels)

    for i in range(len(cm)):
        for j in range(len(cm)):

            text = ax.text(j, i, round(cm[i][j],3),
                           ha="center", va="center", color="w")

    plt.xlabel('Training Vector Doc')
    plt.ylabel('Test Vector Doc')
    #fig.tight_layout()
    plt.show()

# %%
mean_rank, mean_cosine_simliarity, acc, df = compute_IR_evaluation_scores(training_feature_matrix, val_feature_matrix, train_labels, val_labels)
# Out:
# mean rank 2.6875
# mean cosine similarity 0.22313262553576174
# 6 correct out of 16 / accuracy: 0.375

# %%
#for loop to iterate different k to find the best features 
from sklearn.feature_selection import SelectKBest, chi2
for i in range(0,training_feature_matrix.shape[1],100):
    if i>0:
        selector =  SelectKBest(chi2,k=i)
        training_feature_matrix2 = selector.fit(training_feature_matrix, train_labels)
        features_train_transformed = selector.transform(training_feature_matrix)
    
        #val_feature_matrix2 = selector.fit(val_feature_matrix, val_labels)
        features_val_transformed = selector.transform(val_feature_matrix)
        print('k= ',i, 'mean rank: ', compute_IR_evaluation_scores(features_train_transformed, features_val_transformed, train_labels, val_labels)[0] )
# Out:
# <ipython-input-59-f74403f14492>:7: RuntimeWarning: invalid value encountered in double_scalars
#   manual_cosine_similarity = np.dot(v1, v2)  /(norm(v1) * norm(v2))
# <ipython-input-59-f74403f14492>:7: RuntimeWarning: invalid value encountered in double_scalars
#   manual_cosine_similarity = np.dot(v1, v2)  /(norm(v1) * norm(v2))
# <ipython-input-59-f74403f14492>:7: RuntimeWarning: invalid value encountered in double_scalars
#   manual_cosine_similarity = np.dot(v1, v2)  /(norm(v1) * norm(v2))
# <ipython-input-59-f74403f14492>:7: RuntimeWarning: invalid value encountered in double_scalars
#   manual_cosine_similarity = np.dot(v1, v2)  /(norm(v1) * norm(v2))
# <ipython-input-59-f74403f14492>:7: RuntimeWarning: invalid value encountered in double_scalars
#   manual_cosine_similarity = np.dot(v1, v2)  /(norm(v1) * norm(v2))
# <ipython-input-59-f74403f14492>:7: RuntimeWarning: invalid value encountered in double_scalars
#   manual_cosine_similarity = np.dot(v1, v2)  /(norm(v1) * norm(v2))
# <ipython-input-59-f74403f14492>:7: RuntimeWarning: invalid value encountered in double_scalars
#   manual_cosine_similarity = np.dot(v1, v2)  /(norm(v1) * norm(v2))
# <ipython-input-59-f74403f14492>:7: RuntimeWarning: invalid value encountered in double_scalars
#   manual_cosine_similarity = np.dot(v1, v2)  /(norm(v1) * norm(v2))
# <ipython-input-59-f74403f14492>:7: RuntimeWarning: invalid value encountered in double_scalars
#   manual_cosine_similarity = np.dot(v1, v2)  /(norm(v1) * norm(v2))
# <ipython-input-59-f74403f14492>:7: RuntimeWarning: invalid value encountered in double_scalars
#   manual_cosine_similarity = np.dot(v1, v2)  /(norm(v1) * norm(v2))
# <ipython-input-59-f74403f14492>:7: RuntimeWarning: invalid value encountered in double_scalars
#   manual_cosine_similarity = np.dot(v1, v2)  /(norm(v1) * norm(v2))
# mean rank 8.5
# mean cosine similarity nan
# 1 correct out of 16 / accuracy: 0.0625
# k=
mean rank:  7.8125
# mean rank 7.8125
# mean cosine similarity 0.010991494276628475
# 1 correct out of 16 / accuracy: 0.0625
# k=  3200 mean rank:  7.8125
# mean rank 7.8125
# mean cosine similarity 0.010811376545776994
# 1 correct out of 16 / accuracy: 0.0625
# k=  3300 mean rank:  7.8125
# mean rank 7.625
# mean cosine similarity 0.013056398988327679
# 1 correct out of 16 / accuracy: 0.0625
# k=  3400 mean rank:  7.625
# mean rank 7.6875
# mean cosine similarity 0.012674810027792208
# 1 correct out of 16 / accuracy: 0.0625
# k=  3500 mean rank:  7.6875
# mean rank 7.375
# mean cosine similarity 0.015498132768751052
# 3 correct out of 16 / accuracy: 0.1875
# k=  3600 mean rank:  7.375
# mean rank 7.3125
# mean cosine similarity 0.017235212055480995
# 3 correct out of 16 / accuracy: 0.1875
# k=  3700 mean rank:  7.3125
# mean rank 7.3125
# mean cosine similarity 0.01701968724364313
# 3 correct out of 16 / accuracy: 0.1875
# k=  3800 mean rank:  7.3125
# mean rank 7.3125
# mean cosine similarity 0.01676754304822908
# 3 correct out of 16 / accuracy: 0.1875
# k=  3900 mean rank:  7.3125
# mean rank 7.375
# mean cosine similarity 0.016343660298895817
# 3 correct out of 16 / accuracy: 0.1875
# k=  4000 mean rank:  7.375
# mean rank 7.0625
# mean cosine similarity 0.017659565736237275
# 3 correct out of 16 / accuracy: 0.1875
# k=  4100 mean rank:  7.0625
# mean rank 7.0
# mean cosine similarity 0.018613298894564714
# 4 correct out of 16 / accuracy: 0.25
# k=  4200 mean rank:  7.0
# mean rank 7.0
# mean cosine similarity 0.01940845323812581
# 4 correct out of 16 / accuracy: 0.25
# k=  4300 mean rank:  7.0
# mean rank 7.0625
# mean cosine similarity 0.018988985727388656
# 3 correct out of 16 / accuracy: 0.1875
# k=  4400 mean rank:  7.0625
# mean rank 7.0625
# mean cosine similarity 0.018267745943236366
# 3 correct out of 16 / accuracy: 0.1875
# k=  4500 mean rank:  7.0625
# mean rank 7.125
# mean cosine similarity 0.018065594582527947
# 3 correct out of 16 / accuracy: 0.1875
# k=  4600 mean rank:  7.125
# mean rank 7.1875
# mean cosine similarity 0.017931824993728127
# 3 correct out of 16 / accuracy: 0.1875
# k=  4700 mean rank:  7.1875
# mean rank 7.1875
# mean cosine similarity 0.01763563097085714
# 3 correct out of 16 / accuracy: 0.1875
# k=  4800 mean rank:  7.1875
# mean rank 7.1875
# mean cosine similarity 0.017519979398486832
# 3 correct out of 16 / accuracy: 0.1875
# k=  4900 mean rank:  7.1875
# mean rank 7.3125
# mean cosine similarity 0.017087803852065955
# 3 correct out of 16 / accuracy: 0.1875
# k=  5000 mean rank:  7.3125
# mean rank 7.25
# mean cosine similarity 0.018084594969545453
# 3 correct out of 16 / accuracy: 0.1875
# k=  5100 mean rank:  7.25
# mean rank 7.125
# mean cosine similarity 0.019446813077308688
# 3 correct out of 16 / accuracy: 0.1875
# k=  5200 mean rank:  7.125
# mean rank 7.125
# mean cosine similarity 0.019307194203897392
# 3 correct out of 16 / accuracy: 0.1875
# k=  5300 mean rank:  7.125
# mean rank 7.25
# mean cosine similarity 0.018808614043422923
# 3 correct out of 16 / accuracy: 0.1875
# k=  5400 mean rank:  7.25
# mean rank 7.0
# mean cosine similarity 0.019606396508198468
# 3 correct out of 16 / accuracy: 0.1875
# k=  5500 mean rank:  7.0
# mean rank 6.25
# mean cosine similarity 0.020700248001454827
# 3 correct out of 16 / accuracy: 0.1875
# k=  5600 mean rank:  6.25
# mean rank 6.125
# mean cosine similarity 0.022183745571610916
# 4 correct out of 16 / accuracy: 0.25
# k=  5700 mean rank:  6.125
# mean rank 6.3125
# mean cosine similarity 0.02263548466792935
# 4 correct out of 16 / accuracy: 0.25
# k=  5800 mean rank:  6.3125
# mean rank 6.25
# mean cosine similarity 0.024849540731547645
# 4 correct out of 16 / accuracy: 0.25
# k=  5900 mean rank:  6.25
# mean rank 6.375
# mean cosine similarity 0.02545751177428835
# 4 correct out of 16 / accuracy: 0.25
# k=  6000 mean rank:  6.375
# mean rank 6.0
# mean cosine similarity 0.0253156651570497
# 5 correct out of 16 / accuracy: 0.3125
# k=  6100 mean rank:  6.0
# mean rank 6.25
# mean cosine similarity 0.02473884730234691
# 5 correct out of 16 / accuracy: 0.3125
# k=  6200 mean rank:  6.25
# mean rank 5.6875
# mean cosine similarity 0.027404937624535143
# 6 correct out of 16 / accuracy: 0.375
# k=  6300 mean rank:  5.6875
# mean rank 5.375
# mean cosine similarity 0.028402924800116768
# 6 correct out of 16 / accuracy: 0.375
# k=  6400 mean rank:  5.375
# mean rank 5.375
# mean cosine similarity 0.02825050555548996
# 6 correct out of 16 / accuracy: 0.375
# k=  6500 mean rank:  5.375
# mean rank 5.5
# mean cosine similarity 0.027388461018570044
# 5 correct out of 16 / accuracy: 0.3125
# k=  6600 mean rank:  5.5
# mean rank 5.0
# mean cosine similarity 0.028143015346776677
# 5 correct out of 16 / accuracy: 0.3125
# k=  6700 mean rank:  5.0
# mean rank 5.125
# mean cosine similarity 0.027499050226058648
# 5 correct out of 16 / accuracy: 0.3125
# k=  6800 mean rank:  5.125
# mean rank 5.0
# mean cosine similarity 0.02827581056700503
# 5 correct out of 16 / accuracy: 0.3125
# k=  6900 mean rank:  5.0
# mean rank 5.0
# mean cosine similarity 0.02864198395422022
# 5 correct out of 16 / accuracy: 0.3125
# k=  7000 mean rank:  5.0
# mean rank 5.125
# mean cosine similarity 0.028031505042169894
# 5 correct out of 16 / accuracy: 0.3125
# k=  7100 mean rank:  5.125
# mean rank 5.0625
# mean cosine similarity 0.02839633055502246
# 5 correct out of 16 / accuracy: 0.3125
# k=  7200 mean rank:  5.0625
# mean rank 5.25
# mean cosine similarity 0.029073794029465146
# 5 correct out of 16 / accuracy: 0.3125
# k=  7300 mean rank:  5.25
# mean rank 5.1875
# mean cosine similarity 0.029353068759622652
# 6 correct out of 16 / accuracy: 0.375
# k=  7400 mean rank:  5.1875
# mean rank 5.3125
# mean cosine similarity 0.0291491209141968
# 4 correct out of 16 / accuracy: 0.25
# k=  7500 mean rank:  5.3125
# mean rank 5.375
# mean cosine similarity 0.028551512473742127
# 4 correct out of 16 / accuracy: 0.25
# k=  7600 mean rank:  5.375
# mean rank 5.3125
# mean cosine similarity 0.029448185579240796
# 5 correct out of 16 / accuracy: 0.3125
# k=  7700 mean rank:  5.3125
# mean rank 5.4375
# mean cosine similarity 0.03146925933541375
# 5 correct out of 16 / accuracy: 0.3125
# k=  7800 mean rank:  5.4375
# mean rank 4.75
# mean cosine similarity 0.032393011967261756
# 5 correct out of 16 / accuracy: 0.3125
# k=  7900 mean rank:  4.75
# mean rank 4.6875
# mean cosine similarity 0.03244530379382217
# 5 correct out of 16 / accuracy: 0.3125
# k=  8000 mean rank:  4.6875
# mean rank 4.8125
# mean cosine similarity 0.03240374067873608
# 5 correct out of 16 / accuracy: 0.3125
# k=  8100 mean rank:  4.8125
# mean rank 4.6875
# mean cosine similarity 0.03395345803729023
# 6 correct out of 16 / accuracy: 0.375
# k=  8200 mean rank:  4.6875
# mean rank 4.625
# mean cosine similarity 0.035994483440086864
# 6 correct out of 16 / accuracy: 0.375
# k=  8300 mean rank:  4.625
# mean rank 4.8125
# mean cosine similarity 0.037014944995730846
# 5 correct out of 16 / accuracy: 0.3125
# k=  8400 mean rank:  4.8125
# mean rank 4.875
# mean cosine similarity 0.03649262546216691
# 5 correct out of 16 / accuracy: 0.3125
# k=  8500 mean rank:  4.875
# mean rank 4.5
# mean cosine similarity 0.038303279234997184
# 6 correct out of 16 / accuracy: 0.375
# k=  8600 mean rank:  4.5
# mean rank 4.0
# mean cosine similarity 0.040661454981851086
# 6 correct out of 16 / accuracy: 0.375
# k=  8700 mean rank:  4.0
# mean rank 4.0
# mean cosine similarity 0.04117955939184609
# 6 correct out of 16 / accuracy: 0.375
# k=  8800 mean rank:  4.0
# mean rank 3.75
# mean cosine similarity 0.043167237961687324
# 7 correct out of 16 / accuracy: 0.4375
# k=  8900 mean rank:  3.75
# mean rank 3.125
# mean cosine similarity 0.04640653033217225
# 6 correct out of 16 / accuracy: 0.375
# k=  9000 mean rank:  3.125
# mean rank 3.125
# mean cosine similarity 0.048253926905238304
# 5 correct out of 16 / accuracy: 0.3125
# k=  9100 mean rank:  3.125
# mean rank 3.1875
# mean cosine similarity 0.05077066764801974
# 7 correct out of 16 / accuracy: 0.4375
# k=  9200 mean rank:  3.1875
# mean rank 3.0625
# mean cosine similarity 0.05290411733475825
# 6 correct out of 16 / accuracy: 0.375
# k=  9300 mean rank:  3.0625
# mean rank 3.1875
# mean cosine similarity 0.054683912955413035
# 8 correct out of 16 / accuracy: 0.5
# k=  9400 mean rank:  3.1875
# mean rank 3.0
# mean cosine similarity 0.05909572997943341
# 8 correct out of 16 / accuracy: 0.5
# k=  9500 mean rank:  3.0
# mean rank 2.6875
# mean cosine similarity 0.06723353790687588
# 8 correct out of 16 / accuracy: 0.5
# k=  9600 mean rank:  2.6875
# mean rank 2.25
# mean cosine similarity 0.0717558623677097
# 10 correct out of 16 / accuracy: 0.625
# k=  9700 mean rank:  2.25
# mean rank 2.4375
# mean cosine similarity 0.07406525019632977
# 8 correct out of 16 / accuracy: 0.5
# k=  9800 mean rank:  2.4375
# mean rank 2.3125
# mean cosine similarity 0.08311842805135185
# 8 correct out of 16 / accuracy: 0.5
# k=  9900 mean rank:  2.3125
# mean rank 2.1875
# mean cosine similarity 0.09141157560806952
# 8 correct out of 16 / accuracy: 0.5
# k=  10000 mean rank:  2.1875
# mean rank 2.1875
# mean cosine similarity 0.1021249861351495
# 8 correct out of 16 / accuracy: 0.5
# k=  10100 mean rank:  2.1875
# mean rank 2.0625
# mean cosine similarity 0.11447674882565274
# 8 correct out of 16 / accuracy: 0.5
# k=  10200 mean rank:  2.0625
# mean rank 2.3125
# mean cosine similarity 0.13613070439389727
# 6 correct out of 16 / accuracy: 0.375
# k=  10300 mean rank:  2.3125
# mean rank 2.25
# mean cosine similarity 0.1784386994854676
# 7 correct out of 16 / accuracy: 0.4375
# k=  10400 mean rank:  2.25
# mean rank 2.625
# mean cosine similarity 0.22014515665564693
# 7 correct out of 16 / accuracy: 0.4375
# k=  10500 mean rank:  2.625

# %% [markdown]
# ### Final best result for Task 3: it seems the result is not as good as the one in Task2. (Task2 best result: 1.6875)

# %%
#the best solution for Task2
from sklearn.feature_selection import SelectKBest, chi2
selector =  SelectKBest(chi2,k=10200)
training_feature_matrix2 = selector.fit(training_feature_matrix, train_labels)
features_train_transformed = selector.transform(training_feature_matrix)
features_val_transformed = selector.transform(val_feature_matrix)
mean_rank, mean_cosine_simliarity, acc, df0 = compute_IR_evaluation_scores(features_train_transformed, features_val_transformed, train_labels, val_labels)
# Out:
# mean rank 2.0625
# mean cosine similarity 0.11447674882565274
# 8 correct out of 16 / accuracy: 0.5

# %% [markdown]
# # Task 4. Improve the vectorization method
# Use a matrix transformation technique like TF-IDF (https://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfTransformer.html) to improve the `create_document_matrix_from_corpus` function, which currently only uses a dictionary vectorizor (`DictVectorizer`) which straight-forwardly maps from the feature dictionaries produced for each character document to a sparse matrix.

# %% [markdown]
# ### Answer: to avoid confusion, please run all the codes from below as the start point.
# In this question, changes have been made mainly in two functions, they are to_feature_vector_dictionary3() and create_document_matrix_from_corpus3() for implement tdidf matrix. I have tried to use raw data and pre-processed data, and found out the latter returns a better performance.
#
# The final evaluation mean rank is 1.1875. It is the best result among Task 1 - 4.

# %%
import string
import re
import numpy as np
from numpy.linalg import norm
import pandas as pd
from collections import Counter, OrderedDict

import seaborn as sns
import matplotlib.pyplot as plt

import nltk

from sklearn.feature_extraction import DictVectorizer

# %matplotlib inline
pd.options.display.max_colwidth=500

# %%
# Load in training data and display in pandas dataframe
train_path='training.csv'
all_train_data = pd.read_csv(train_path,  delimiter="\t", skip_blank_lines = True)
test_path ='test.csv'
test_data = pd.read_csv(test_path,  delimiter="\t", skip_blank_lines = True)

# Inspect
all_train_data.head()
# Out:
#    Episode  Scene                   Scene_info Character_name  \
# 0     1350      1  DESERTED CAR PARK EXT NIGHT        SHIRLEY
# 1     1350      1  DESERTED CAR PARK EXT NIGHT          OTHER
# 2     1350      2                R&R INT NIGHT           JACK
# 3     1350      2                R&R INT NIGHT         RONNIE
# 4     1350      2                R&R INT NIGHT           JACK
#
#                                                                                                     Line  \
# 0                                     Look at ya, not a mark on ya. And you think you're an unlucky man.
# 1                                                                                               Shirl...
# 2                                               Oi. Where have you been? Huh? What were the texts about?
# 3                                                Nothing. Nothing. I'll be with you in two minutes yeah?
# 4  Well I've got mates here I wanted to have a chat with them, instead I've been serving behind the bar.
#
#    Gender
# 0  FEMALE
# 1    MALE
# 2    MALE
# 3  FEMALE
# 4    MALE

# %%
#Inspect
test_data.head()
# Out:
#    Episode  Scene                   Scene_info Character_name  \
# 0     1350      7  DESERTED CAR PARK EXT NIGHT        SHIRLEY
# 1     1350      7  DESERTED CAR PARK EXT NIGHT          OTHER
# 2     1350      7  DESERTED CAR PARK EXT NIGHT        SHIRLEY
# 3     1350      7  DESERTED CAR PARK EXT NIGHT          OTHER
# 4     1350      7  DESERTED CAR PARK EXT NIGHT        SHIRLEY
#
#                                                                                                                                                                                    Line  \
# 0  You'll be alright Kevin. They're gonna cut you out. It's going to be alright. Come on, just talk to me. Just, just talk to me. Call me names- let me know you're still here with me.
# 1                                                                                                                                           ...I've got pins and needles in my fingers.
# 2                                                                                                                                                                      That's the cold.
# 3                                                                                                                                                         Yeah. It's all shutting down.
# 4                                                                                                                                                                   It's just the cold.
#
#    Gender
# 0  FEMALE
# 1    MALE
# 2  FEMALE
# 3    MALE
# 4  FEMALE

# %%
# Split into training and test data for heldout validation with random samples of 9:1 train/heldout split
from random import shuffle, seed

seed(0) # set a seed for reproducibility so same split is used each time

epsiode_scene_column = all_train_data.Episode.astype(str) + "-" + all_train_data.Scene.astype(str)
all_train_data['episode_scene'] = epsiode_scene_column
episode_scenes = sorted(list(set([x for x in epsiode_scene_column.values]))) # set function is random, need to sort!

shuffle(episode_scenes)

print(len(episode_scenes))
episode_split = int(0.9*len(episode_scenes))
training_ep_scenes = episode_scenes[:episode_split]
test_ep_scenes = episode_scenes[episode_split:]
print(len(training_ep_scenes), len(test_ep_scenes))

def train_or_heldout_eps(val):
    if val in training_ep_scenes:
        return "training"
    return "heldout"

all_train_data['train_heldout'] = all_train_data['episode_scene'].apply(train_or_heldout_eps)
# Out:
# 1394
# 1254 140

# %%
print('Raw Data: ',np.shape(all_train_data))
train_data = all_train_data[all_train_data['train_heldout']=='training']
val_data = all_train_data[all_train_data['train_heldout']=='heldout']
print('Train set: ',np.shape(train_data))
print('Validation set: ',np.shape(val_data))
# Out:
# Raw Data:  (15319, 8)
# Train set:  (13638, 8)
# Validation set:  (1681, 8)

# %%
train_data.head()
# Out:
#    Episode  Scene                   Scene_info Character_name  \
# 0     1350      1  DESERTED CAR PARK EXT NIGHT        SHIRLEY
# 1     1350      1  DESERTED CAR PARK EXT NIGHT          OTHER
# 2     1350      2                R&R INT NIGHT           JACK
# 3     1350      2                R&R INT NIGHT         RONNIE
# 4     1350      2                R&R INT NIGHT           JACK
#
#                                                                                                     Line  \
# 0                                     Look at ya, not a mark on ya. And you think you're an unlucky man.
# 1                                                                                               Shirl...
# 2                                               Oi. Where have you been? Huh? What were the texts about?
# 3                                                Nothing. Nothing. I'll be with you in two minutes yeah?
# 4  Well I've got mates here I wanted to have a chat with them, instead I've been serving behind the bar.
#
#    Gender episode_scene train_heldout
# 0  FEMALE        1350-1      training
# 1    MALE        1350-1      training
# 2    MALE        1350-2      training
# 3  FEMALE        1350-2      training
# 4    MALE        1350-2      training

# %%
val_data.head()
# Out:
#     Episode  Scene                  Scene_info Character_name  \
# 56     1350     18  BRANNINGS' HOUSE INT NIGHT          TANYA
# 57     1350     18  BRANNINGS' HOUSE INT NIGHT            MAX
# 58     1350     18  BRANNINGS' HOUSE INT NIGHT           SEAN
# 59     1350     18  BRANNINGS' HOUSE INT NIGHT          TANYA
# 60     1350     18  BRANNINGS' HOUSE INT NIGHT            MAX
#
#                                                                                                                                                                                                           Line  \
# 56                                                                                                                                                                                                 Who's that?
# 57                                                                                                                                              Tanya! Tanya it's me. I wanna give Oscar a New Year kiss. Tan?
# 58                                                                                                                                                                                    Right. I'll have a word.
# 59                                                                                                                    No no no leave it, leave it. He ain't got a key. He'll go away. Do you want some crisps?
# 60  Who, who you got in there, Tan? Tan, I've got a right to know who my kids are being exposed to. I bet you ain't got anyone have ya? You're just sitting there with a bottle of wine all on your Jack, Tan?
#
#     Gender episode_scene train_heldout
# 56  FEMALE       1350-18       heldout
# 57    MALE       1350-18       heldout
# 58    MALE       1350-18       heldout
# 59  FEMALE       1350-18       heldout
# 60    MALE       1350-18       heldout

# %%
# Create one document per character
def create_character_document_from_dataframe(df, max_line_count):
    """Returns a dict with the name of the character as key,
    their lines joined together as a single string, with end of line _EOL_
    markers between them.
    
    ::max_line_count:: the maximum number of lines to be added per character
    """
    character_docs = {}
    character_line_count = {}
    character_gender = {}
    for line, name, gender in zip(df.Line, df.Character_name, df.Gender):
        
        if not name in character_docs.keys():
            character_docs[name] = ""
            character_line_count[name] = 0
        if character_line_count[name]==max_line_count:
            continue
        character_docs[name] += str(line)   + " _EOL_ "
        
        character_line_count[name]+=1
        
    #obtain name gender mapping info for Q2
    for name, gender in zip(df.Character_name, df.Gender):
        if name != "OTHER": #as other has diff gender, do not extract its gender
            character_gender[name] =str(gender)
                
    print("name-gender mapping: ", character_gender)
    print("\nlines per character", character_line_count)
    return character_docs

# %%
# print out the number of words each character has in the training set
# only use the first 360 lines of each character
train_character_docs = create_character_document_from_dataframe(train_data, max_line_count=360)
print('Num. Characters: ',len(train_character_docs.keys()),"\n")
total_words = 0
for name in train_character_docs.keys():
    print(name, 'Number of Words: ',len(train_character_docs[name].split()))
    total_words += len(train_character_docs[name].split())
print("total words", total_words)
# Out:
# name-gender mapping:  {'SHIRLEY': 'FEMALE', 'JACK': 'MALE', 'RONNIE': 'FEMALE', 'TANYA': 'FEMALE', 'SEAN': 'MALE', 'ROXY': 'FEMALE', 'HEATHER': 'FEMALE', 'MAX': 'MALE', 'IAN': 'MALE', 'JANE': 'FEMALE', 'STACEY': 'FEMALE', 'PHIL': 'MALE', 'MINTY': 'MALE', 'CHRISTIAN': 'MALE', 'CLARE': 'FEMALE'}
#
# lines per character {'SHIRLEY': 360, 'OTHER': 360, 'JACK': 360, 'RONNIE': 360, 'TANYA': 360, 'SEAN': 360, 'ROXY': 360, 'HEATHER': 360, 'MAX': 360, 'IAN': 360, 'JANE': 360, 'STACEY': 360, 'PHIL': 360, 'MINTY': 360, 'CHRISTIAN': 342, 'CLARE': 352}
# Num. Characters:  16
#
# SHIRLEY Number of Words:  3848
# OTHER Number of Words:  3244
# JACK Number of Words:  4435
# RONNIE Number of Words:  3442
# TANYA Number of Words:  3786
# SEAN Number of Words:  3637
# ROXY Number of Words:  3838
# HEATHER Number of Words:  4098
# MAX Number of Words:  4363
# IAN Number of Words:  4332
# JANE Number of Words:  3648
# STACEY Number of Words:  3913
# PHIL Number of Words:  3635
# MINTY Number of Words:  4005
# CHRISTIAN Number of Words:  3738
# CLARE Number of Words:  4344
# total words 62306

# %%
#Task2 version3 updated tokenize with POS tags and sentiment score generated
#what it does to the text: sentiment score generated, pos tag generated, lower case, 
#remove punctuation, remove stop words, word stemming

#difference made from Q1: sentiment score added

# import and download relative libraries for tokenize
from nltk.corpus import stopwords
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.tokenize import sent_tokenize, word_tokenize
nltk.download('punkt')
from nltk.stem import PorterStemmer
ps = PorterStemmer()
import nltk
nltk.download('averaged_perceptron_tagger')



def pre_process1(character_text):


    
    wordlist = []
    poslist= []

    #change to lower case
    character_text = character_text.lower()
        
    #remove '_eol_'
    #character_text = character_text.replace("_eol_ ","")
    
    #generate pos tags
    tokens = word_tokenize(character_text)
    wordpos = nltk.pos_tag(tokens)
    
    #remove punctuation
    symbols = "!#$%&()*@+-.,/:;<=>?[\]^`{|}~\n"
    j=0
    for i in range(len(wordpos)):
        for symbol in symbols:
            if wordpos[i-j][0] == symbol:    
                del wordpos[i-j]
                j += 1
              
        
    #remove stop words
    stops = stopwords.words('english')
    k=0
    for i in range(len(wordpos)):
        for stop in stops:
            if wordpos[i-k][0] == stop:    
                del wordpos[i-k]
                k += 1

    for i in range(len(wordpos)):
        word = wordpos[i][0]
        pos = wordpos[i][1]
        wordlist.append(word)
        poslist.append(pos)
 

    #stemming
    wordlist2 = []
    for w in wordlist:
        wordlist2.append(ps.stem(w))
    

    return wordlist2, poslist
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\dandi\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\dandi\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\dandi\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
# create list of pairs of (character name, pre-processed character) 
training_corpus = [(name, pre_process1(doc)[0]) for name, doc in sorted(train_character_docs.items())]
train_labels = [name for name, doc in training_corpus]

# %%
# create list of pairs of (character name, pre-processed pos tags)
training_POS = [(name, pre_process1(doc)[1]) for name, doc in sorted(train_character_docs.items())]

# %%
#training_corpus

# %% [markdown]
# For Task4, changes for the below function to_feature_vector_dictionary3() has been made. Since the later used TDIDF function TfidfVectorizer() has its own calculation of the tokens, the function to_feature_vector_dictionary3() here is just to join all the pre-processed tokens with a white space.

# %%
#modified v4 for Task 4 tdidf
# join all the tokens as a whole and do not do countings
import nltk
nltk.download('averaged_perceptron_tagger')

def to_feature_vector_dictionary3(character_doc):

    #method1: simply join all the words
    new_doc = " ".join(character_doc)
    
    #method2: change word to let it stick with the next word in form word_word+1
    """pbigramlist = []
    for i in range(len(character_doc)):
        
            if len(character_doc)-i>1:
                pbiword = character_doc[i] + '_' + character_doc[i+1]
                pbigramlist.append(pbiword)
    new_doc = " ".join(pbigramlist)"""

    return new_doc
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\dandi\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %% [markdown]
# Changes have been made for the below function create_document_matrix_from_corpus3() for implementing tdidf matrix transforming.

# %%
#updated version4 with tdidf
from sklearn.feature_extraction.text import TfidfVectorizer
#corpusVectorizer = DictVectorizer()   # corpusVectorizor which will just produce sparse vectors from feature dicts
tdidfVectorizer = TfidfVectorizer(sublinear_tf=True) # tf-idf transformer is initialized here, tf is in log

def create_document_matrix_from_corpus3(corpus,fitting=False):
    list_doc = [] # a list to contain all the text in the form of suitable for tdidfVectorizer()
    for name, doc in corpus:
        new_doc = to_feature_vector_dictionary3(doc)
        list_doc.append(new_doc)
    if fitting:
         doc_feature_matrix = tdidfVectorizer.fit_transform(list_doc)
    else:
        doc_feature_matrix = tdidfVectorizer.transform(list_doc)
    
    return doc_feature_matrix    
    
training_feature_matrix = create_document_matrix_from_corpus3(training_corpus,fitting=True)

# %%
training_feature_matrix
# Out:
# <16x3172 sparse matrix of type '<class 'numpy.float64'>'
# 	with 10215 stored elements in Compressed Sparse Row format>

# %%
# get the validation data- only 40 lines used for each character
val_character_docs = create_character_document_from_dataframe(val_data, max_line_count=40)
print('Num. Characters: ',len(val_character_docs.keys()),"\n")
total_words = 0
for name in val_character_docs.keys():
    print(name, 'Num of Words: ',len(val_character_docs[name].split()))
    total_words += len(val_character_docs[name].split())
print("total words", total_words)

# create list of pairs of (character name, pre-processed character) 
val_corpus = [(name, pre_process1(doc)[0]) for name, doc in sorted(val_character_docs.items())]
val_labels = [name for name, doc in val_corpus]
# create list of pairs of (character name, POS tags) 
val_POS = [(name, pre_process1(doc)[1]) for name, doc in sorted(val_character_docs.items())]
# create list of pairs of (character name, sentiment score) 
#val_senti = [(name, pre_process1(doc)[2]) for name, doc in sorted(val_character_docs.items())]
# Out:
# name-gender mapping:  {'TANYA': 'FEMALE', 'MAX': 'MALE', 'SEAN': 'MALE', 'SHIRLEY': 'FEMALE', 'STACEY': 'FEMALE', 'RONNIE': 'FEMALE', 'JACK': 'MALE', 'PHIL': 'MALE', 'IAN': 'MALE', 'JANE': 'FEMALE', 'ROXY': 'FEMALE', 'HEATHER': 'FEMALE', 'MINTY': 'MALE', 'CHRISTIAN': 'MALE', 'CLARE': 'FEMALE'}
#
# lines per character {'TANYA': 40, 'MAX': 40, 'SEAN': 35, 'SHIRLEY': 40, 'OTHER': 40, 'STACEY': 40, 'RONNIE': 40, 'JACK': 40, 'PHIL': 40, 'IAN': 40, 'JANE': 40, 'ROXY': 40, 'HEATHER': 40, 'MINTY': 40, 'CHRISTIAN': 40, 'CLARE': 40}
# Num. Characters:  16
#
# TANYA Num of Words:  438
# MAX Num of Words:  737
# SEAN Num of Words:  366
# SHIRLEY Num of Words:  329
# OTHER Num of Words:  357
# STACEY Num of Words:  412
# RONNIE Num of Words:  464
# JACK Num of Words:  351
# PHIL Num of Words:  475
# IAN Num of Words:  508
# JANE Num of Words:  458
# ROXY Num of Words:  392
# HEATHER Num of Words:  411
# MINTY Num of Words:  470
# CHRISTIAN Num of Words:  489
# CLARE Num of Words:  405
# total words 7062

# %%
# Just transform the val_feature_matrix, don't fit
val_feature_matrix = create_document_matrix_from_corpus3(val_corpus,fitting=False)

# %%
val_feature_matrix
# Out:
# <16x3172 sparse matrix of type '<class 'numpy.float64'>'
# 	with 1991 stored elements in Compressed Sparse Row format>

# %%
def compute_cosine_similarity(v1, v2):
    """Takes a pair of vectors v1 and v2 (1-d arrays e.g. [0, 0.5, 0.5])
    returns the cosine similarity between the vectors
    """
    
    # compute cosine similarity manually
    manual_cosine_similarity = np.dot(v1, v2)  /(norm(v1) * norm(v2))
    
    return manual_cosine_similarity

# %%
def compute_IR_evaluation_scores(train_feature_matrix, test_feature_matrix, train_labels, test_labels):
    """
    Computes an information retrieval based on training data feature matrix and test data feature matrix
    returns 4-tuple:
    ::mean_rank:: mean of the ranking of the target document in terms of similarity to the query/test document
    1 is the best possible score.
    ::mean_cosine_similarity:: mean cosine similarity score for the target document vs. the test document of the same class
    ::accuracy:: proportion of test documents correctly classified
    ::df:: a data frame with all the similarity measures of the test documents vs. train documents
    
    params:
    ::train_feature_matrix:: a numpy matrix N x M shape where N = number of characters M = number of features
    ::test_feature_matrix::  a numpy matrix N x M shape where N = number of characters M = number of features
    ::train_labels:: a list of character names for the training data in order consistent with train_feature_matrix
    ::test_labels:: a list of character names for the test data in order consistent with test_feature_matrix
    """
    rankings = []
    all_cosine_similarities = []
    pairwise_cosine_similarity = []
    pairs = []
    correct = 0
    for i, target in enumerate(test_labels):
        # compare the left out character against the mean
        idx = i 
        fm_1 = test_feature_matrix.toarray()[idx]
        all_sims = {}
        # print("target:", target)
        for j, other in enumerate(train_labels):
            fm_2 = train_feature_matrix.toarray()[j]
            manual_cosine_similarity = compute_cosine_similarity(fm_1, fm_2)
            pairs.append((target, other))
            pairwise_cosine_similarity.append(manual_cosine_similarity)
            if other == target:
                all_cosine_similarities.append(manual_cosine_similarity)
            all_sims[other] = manual_cosine_similarity

            # print(target, other, manual_cosine_similarity)
        sorted_similarities = sorted(all_sims.items(),key=lambda x:x[1],reverse=True)
        # print(sorted_similarities)
        ranking = {key[0]: rank for rank, key in enumerate(sorted_similarities, 1)}
        # print("Ranking for target", ranking[target])
        if ranking[target] == 1:
            correct += 1
        rankings.append(ranking[target])
        # print("*****")
    mean_rank = np.mean(rankings)
    mean_cosine_similarity = np.mean(all_cosine_similarities)
    accuracy = correct/len(test_labels)
    print("mean rank", np.mean(rankings))
    print("mean cosine similarity", mean_cosine_similarity)
    print(correct, "correct out of", len(test_labels), "/ accuracy:", accuracy )
    
    # get a dafaframe showing all the similarity scores of training vs test docs
    df = pd.DataFrame({'doc1': [x[0] for x in pairs], 'doc2': [x[1] for x in pairs],
                       'similarity': pairwise_cosine_similarity})

    # display characters which are most similar and least similar
    df.loc[[df.similarity.values.argmax(), df.similarity.values.argmin()]]
    return (mean_rank, mean_cosine_similarity, accuracy, df)

# %%
def plot_heat_map_similarity(df):
    """Takes a dataframe with header 'doc1, doc2, similarity'
    Plots a heatmap based on the similarity scores.
    """
    test_labels =  sorted(list(set(df.sort_values(['doc1'])['doc1'])))
    # add padding 1.0 values to either side
    cm = [[1.0,] * (len(test_labels)+2)]
    for target in test_labels:
        new_row = [1.0]
        for x in df.sort_values(['doc1', 'doc2'])[df['doc1']==target]['similarity']:
            new_row.append(x)
        new_row.append(1.0)
        cm.append(new_row)
    cm.append([1.0,] * (len(test_labels)+2))
    #print(cm)
    labels = [""] + test_labels + [""]
    fig = plt.figure(figsize=(20,20))
    ax = fig.add_subplot(111)
    cax = ax.matshow(cm)
    plt.title('Similarity matrix between documents as vectors')
    fig.colorbar(cax)
    ax.set_xticks(np.arange(len(labels)))
    ax.set_yticks(np.arange(len(labels)))
    ax.set_xticklabels( labels, rotation=45)
    ax.set_yticklabels( labels)

    for i in range(len(cm)):
        for j in range(len(cm)):

            text = ax.text(j, i, round(cm[i][j],3),
                           ha="center", va="center", color="w")

    plt.xlabel('Training Vector Doc')
    plt.ylabel('Test Vector Doc')
    #fig.tight_layout()
    plt.show()

# %% [markdown]
# ### Evaluation for Task 4

# %% [markdown]
# experiment 1 - result for TfidfVectorizer use all default parameters:mean rank 1.75 (please note: as this a historical experiment code, re-run the code will not produce the same result.)

# %%
#please do not re-run this code, as this is a historical experiment
mean_rank, mean_cosine_simliarity, acc, df = compute_IR_evaluation_scores(training_feature_matrix, val_feature_matrix, train_labels, val_labels)
# Out:
# mean rank 1.75
# mean cosine similarity 0.8715455591225224
# 12 correct out of 16 / accuracy: 0.75

# %% [markdown]
# experiment 2 - result for TfidfVectorizer use sublinear_tf=True:

# %%
#sublinear_tf=True tf is calculated in log
mean_rank, mean_cosine_simliarity, acc, df = compute_IR_evaluation_scores(training_feature_matrix, val_feature_matrix, train_labels, val_labels)
# Out:
# mean rank 1.1875
# mean cosine similarity 0.32108534404951544
# 14 correct out of 16 / accuracy: 0.875

# %% [markdown]
# # Task 5. Select and test the best vector representation method

# %% [markdown]
# ### Answer: To avoid confusion, please run from the beggining of the code from here:
# In Task 5, I have used the best combination of techniques I tried in Task1-3 to train for all the training data and test on the whole test file. The final score is mean rank - 1.4375.

# %%
import string
import re
import numpy as np
from numpy.linalg import norm
import pandas as pd
from collections import Counter, OrderedDict

import seaborn as sns
import matplotlib.pyplot as plt

import nltk

from sklearn.feature_extraction import DictVectorizer

# %matplotlib inline
pd.options.display.max_colwidth=500

# %%
# Load in training data and display in pandas dataframe
train_path='training.csv'
all_train_data = pd.read_csv(train_path,  delimiter="\t", skip_blank_lines = True)
test_path ='test.csv'
test_data = pd.read_csv(test_path,  delimiter="\t", skip_blank_lines = True)

# Inspect
all_train_data.head()
# Out:
#    Episode  Scene                   Scene_info Character_name  \
# 0     1350      1  DESERTED CAR PARK EXT NIGHT        SHIRLEY
# 1     1350      1  DESERTED CAR PARK EXT NIGHT          OTHER
# 2     1350      2                R&R INT NIGHT           JACK
# 3     1350      2                R&R INT NIGHT         RONNIE
# 4     1350      2                R&R INT NIGHT           JACK
#
#                                                                                                     Line  \
# 0                                     Look at ya, not a mark on ya. And you think you're an unlucky man.
# 1                                                                                               Shirl...
# 2                                               Oi. Where have you been? Huh? What were the texts about?
# 3                                                Nothing. Nothing. I'll be with you in two minutes yeah?
# 4  Well I've got mates here I wanted to have a chat with them, instead I've been serving behind the bar.
#
#    Gender
# 0  FEMALE
# 1    MALE
# 2    MALE
# 3  FEMALE
# 4    MALE

# %%
test_data.head()
# Out:
#    Episode  Scene                   Scene_info Character_name  \
# 0     1350      7  DESERTED CAR PARK EXT NIGHT        SHIRLEY
# 1     1350      7  DESERTED CAR PARK EXT NIGHT          OTHER
# 2     1350      7  DESERTED CAR PARK EXT NIGHT        SHIRLEY
# 3     1350      7  DESERTED CAR PARK EXT NIGHT          OTHER
# 4     1350      7  DESERTED CAR PARK EXT NIGHT        SHIRLEY
#
#                                                                                                                                                                                    Line  \
# 0  You'll be alright Kevin. They're gonna cut you out. It's going to be alright. Come on, just talk to me. Just, just talk to me. Call me names- let me know you're still here with me.
# 1                                                                                                                                           ...I've got pins and needles in my fingers.
# 2                                                                                                                                                                      That's the cold.
# 3                                                                                                                                                         Yeah. It's all shutting down.
# 4                                                                                                                                                                   It's just the cold.
#
#    Gender
# 0  FEMALE
# 1    MALE
# 2  FEMALE
# 3    MALE
# 4  FEMALE

# %%
#add episode_scene column for train data
epsiode_scene_column = all_train_data.Episode.astype(str) + "-" + all_train_data.Scene.astype(str)
all_train_data['episode_scene'] = epsiode_scene_column
episode_scenes = sorted(list(set([x for x in epsiode_scene_column.values]))) # set function is random, need to sort!
all_train_data
# Out:
#        Episode  Scene                   Scene_info Character_name  \
# 0         1350      1  DESERTED CAR PARK EXT NIGHT        SHIRLEY
# 1         1350      1  DESERTED CAR PARK EXT NIGHT          OTHER
# 2         1350      2                R&R INT NIGHT           JACK
# 3         1350      2                R&R INT NIGHT         RONNIE
# 4         1350      2                R&R INT NIGHT           JACK
# ...        ...    ...                          ...            ...
# 15314     1399     55         SQUARE EXT DAY LIGHT          OTHER
# 15315     1399     55         SQUARE EXT DAY LIGHT            MAX
# 15316     1399     55         SQUARE EXT DAY LIGHT          OTHER
# 15317     1399     55         SQUARE EXT DAY LIGHT            MAX
# 15318     1399     55         SQUARE EXT DAY LIGHT          OTHER
#
#                                                                                                               Line  \
# 0                                               Look at ya, not a mark on ya. And you think you're an unlucky man.
# 1                                                                                                         Shirl...
# 2                                                         Oi. Where have you been? Huh? What were the texts about?
# 3                                                          Nothing. Nothing. I'll be with you in two minutes yeah?
# 4            Well I've got mates here I wanted to have a chat with them, instead I've been serving behind the bar.
# ...                                                                                                            ...
# 15314  Dad? Okay ... alright, just one drink alright. But that's all. It doesn't mean anything. It's just a drink.
# 15315                                                   Thanks Bradley. Thanks mate... It means the world to me...
# 15316                                                                                               You alright...
# 15317                                                                                  Yeah, yeah, yeah. I'm fine.
# 15318                                                                                           Well, let me know.
#
#        Gender episode_scene
# 0      FEMALE        1350-1
# 1        MALE        1350-1
# 2        MALE        1350-2
# 3      FEMALE        1350-2
# 4        MALE        1350-2
# ...       ...           ...
# 15314    MALE       1399-55
# 15315    MALE       1399-55
# 15316    MALE       1399-55
# 15317    MALE       1399-55
# 15318    MALE       1399-55
#
# [15319 rows x 7 columns]

# %%
#add episode_scene column for test data
epsiode_scene_column = test_data.Episode.astype(str) + "-" + test_data.Scene.astype(str)
test_data['episode_scene'] = epsiode_scene_column
episode_scenes = sorted(list(set([x for x in epsiode_scene_column.values]))) # set function is random, need to sort!
test_data.head()
# Out:
#    Episode  Scene                   Scene_info Character_name  \
# 0     1350      7  DESERTED CAR PARK EXT NIGHT        SHIRLEY
# 1     1350      7  DESERTED CAR PARK EXT NIGHT          OTHER
# 2     1350      7  DESERTED CAR PARK EXT NIGHT        SHIRLEY
# 3     1350      7  DESERTED CAR PARK EXT NIGHT          OTHER
# 4     1350      7  DESERTED CAR PARK EXT NIGHT        SHIRLEY
#
#                                                                                                                                                                                    Line  \
# 0  You'll be alright Kevin. They're gonna cut you out. It's going to be alright. Come on, just talk to me. Just, just talk to me. Call me names- let me know you're still here with me.
# 1                                                                                                                                           ...I've got pins and needles in my fingers.
# 2                                                                                                                                                                      That's the cold.
# 3                                                                                                                                                         Yeah. It's all shutting down.
# 4                                                                                                                                                                   It's just the cold.
#
#    Gender episode_scene
# 0  FEMALE        1350-7
# 1    MALE        1350-7
# 2  FEMALE        1350-7
# 3    MALE        1350-7
# 4  FEMALE        1350-7

# %%
print('Train set: ',np.shape(all_train_data))
print('Test set: ',np.shape(test_data))
# Out:
# Train set:  (15319, 7)
# Test set:  (1767, 7)

# %%
# Create one document per character
def create_character_document_from_dataframe(df, max_line_count):
    """Returns a dict with the name of the character as key,
    their lines joined together as a single string, with end of line _EOL_
    markers between them.
    
    ::max_line_count:: the maximum number of lines to be added per character
    """
    character_docs = {}
    character_line_count = {}
    character_gender = {}
    for line, name, gender in zip(df.Line, df.Character_name, df.Gender):
        
        if not name in character_docs.keys():
            character_docs[name] = ""
            character_line_count[name] = 0
        if character_line_count[name]==max_line_count:
            continue
        character_docs[name] += str(line)   + " _EOL_ "
        
        character_line_count[name]+=1
        
    #obtain name gender mapping info for Q2
    for name, gender in zip(df.Character_name, df.Gender):
        if name != "OTHER": #as other has diff gender, do not extract its gender
            character_gender[name] =str(gender)
                
    print("name-gender mapping: ", character_gender)
    print("\nlines per character", character_line_count)
    return character_docs

# %%
# print out the number of words each character has in the training set
# only use the first 400 lines of each character
train_character_docs = create_character_document_from_dataframe(all_train_data, max_line_count=400)
print('Num. Characters: ',len(train_character_docs.keys()),"\n")
total_words = 0
for name in train_character_docs.keys():
    print(name, 'Number of Words: ',len(train_character_docs[name].split()))
    total_words += len(train_character_docs[name].split())
print("total words", total_words)
# Out:
# name-gender mapping:  {'SHIRLEY': 'FEMALE', 'JACK': 'MALE', 'RONNIE': 'FEMALE', 'TANYA': 'FEMALE', 'SEAN': 'MALE', 'ROXY': 'FEMALE', 'HEATHER': 'FEMALE', 'MAX': 'MALE', 'IAN': 'MALE', 'JANE': 'FEMALE', 'STACEY': 'FEMALE', 'PHIL': 'MALE', 'MINTY': 'MALE', 'CHRISTIAN': 'MALE', 'CLARE': 'FEMALE'}
#
# lines per character {'SHIRLEY': 400, 'OTHER': 400, 'JACK': 400, 'RONNIE': 400, 'TANYA': 400, 'SEAN': 400, 'ROXY': 400, 'HEATHER': 400, 'MAX': 400, 'IAN': 400, 'JANE': 400, 'STACEY': 400, 'PHIL': 400, 'MINTY': 400, 'CHRISTIAN': 385, 'CLARE': 400}
# Num. Characters:  16
#
# SHIRLEY Number of Words:  4233
# OTHER Number of Words:  3606
# JACK Number of Words:  4786
# RONNIE Number of Words:  3872
# TANYA Number of Words:  4214
# SEAN Number of Words:  4026
# ROXY Number of Words:  4200
# HEATHER Number of Words:  4504
# MAX Number of Words:  5107
# IAN Number of Words:  4863
# JANE Number of Words:  4117
# STACEY Number of Words:  4325
# PHIL Number of Words:  4103
# MINTY Number of Words:  4391
# CHRISTIAN Number of Words:  4250
# CLARE Number of Words:  4844
# total words 69441

# %%
#Q2 version3 updated tokenize with POS tags and sentiment score generated
#what it does to the text: sentiment score generated, pos tag generated, lower case, 
#remove punctuation, remove stop words, word stemming

#difference made from Q1: sentiment score added

# import and download relative libraries for tokenize
from nltk.corpus import stopwords
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.tokenize import sent_tokenize, word_tokenize
nltk.download('punkt')
from nltk.stem import PorterStemmer
ps = PorterStemmer()
import nltk
nltk.download('averaged_perceptron_tagger')



def pre_process1(character_text):


    
    wordlist = []
    poslist= []

    #change to lower case
    character_text = character_text.lower()
        
    #remove '_eol_'
    #character_text = character_text.replace("_eol_ ","")
    
    #generate pos tags
    tokens = word_tokenize(character_text)
    wordpos = nltk.pos_tag(tokens)
    
    #remove punctuation
    symbols = "!#$%&()*@+-.,/:;<=>?[\]^`{|}~\n"
    j=0
    for i in range(len(wordpos)):
        for symbol in symbols:
            if wordpos[i-j][0] == symbol:    
                del wordpos[i-j]
                j += 1
              
        
    #remove stop words
    stops = stopwords.words('english')
    k=0
    for i in range(len(wordpos)):
        for stop in stops:
            if wordpos[i-k][0] == stop:    
                del wordpos[i-k]
                k += 1

    for i in range(len(wordpos)):
        word = wordpos[i][0]
        pos = wordpos[i][1]
        wordlist.append(word)
        poslist.append(pos)
 

    #stemming
    wordlist2 = []
    for w in wordlist:
        wordlist2.append(ps.stem(w))
    

    return wordlist2, poslist
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\dandi\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\dandi\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\dandi\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
# create list of pairs of (character name, pre-processed character) 
training_corpus = [(name, pre_process1(doc)[0]) for name, doc in sorted(train_character_docs.items())]
train_labels = [name for name, doc in training_corpus]

# %%
# create list of pairs of (character name, pre-processed pos tags)
training_POS = [(name, pre_process1(doc)[1]) for name, doc in sorted(train_character_docs.items())]

# %%
#training_corpus

# %%
#modified v3

import nltk
nltk.download('averaged_perceptron_tagger')
# !pip3 install afinn
from afinn import Afinn

def to_feature_vector_dictionary2(character_doc, tag, name):

    wordlist1 = [] #list store previous bigram

    senti_list = [] #list store sentiment scores for each token


    #counts = Counter(character_doc)  # for now a simple count
    #counts = dict(counts)
    counts = {}
    
    #add POS tag features
    #pos = Counter(tag)
    #pos = dict(pos)
    #counts.update(pos)
    
    #sentiment score analysis for each word
    afinn = Afinn()
    for j in character_doc:
        word_senti =  str(afinn.score(j))
        senti_list.append(word_senti)
    
    #experiment1 target word and its tag
    '''for i in range(len(character_doc)):
        word = character_doc[i] +'@'+ tag[i]
        wordlist1.append(word)

    word_counts = Counter(wordlist1)
    word_counts = dict(word_counts)
    for a in word_counts:
        counts[a] = 0
        counts[a] +=1'''
    
    #experiment2 target word and one prev word&tag
    '''for i in range(len(character_doc)):
        if i>0:
            word = character_doc[i-1] +'@'+ tag[i-1]+'_'+character_doc[i]+'@'+tag[i]
            wordlist1.append(word)

    word_counts = Counter(wordlist1)
    word_counts = dict(word_counts)
    for a in word_counts:
        counts[a] = 0
        counts[a] +=1'''
        
    #experiment 3 target word and one after word&tag
    '''for i in range(len(character_doc)):        
            if len(character_doc)-i>1:
                word = character_doc[i] +'@'+tag[i]+'_' + character_doc[i+1]+'@'+tag[i+1]    
            wordlist1.append(word)

    word_counts = Counter(wordlist1)
    word_counts = dict(word_counts)
    for a in word_counts:
        counts[a] = 0
        counts[a] +=1'''
        
    #experiment4 target and one after word
    '''for i in range(len(character_doc)):        
            if len(character_doc)-i>1:
                word = character_doc[i] +'_' + character_doc[i+1]    
            wordlist1.append(word)

    word_counts = Counter(wordlist1)
    word_counts = dict(word_counts)
    for a in word_counts:
        counts[a] = 0
        counts[a] +=1'''
    
    #experiment 5 target and one prev word
    '''for i in range(len(character_doc)):
        if i>0:
            word = character_doc[i-1] +'_'+character_doc[i]
            wordlist1.append(word)

    word_counts = Counter(wordlist1)
    word_counts = dict(word_counts)
    for a in word_counts:
        counts[a] = 0
        counts[a] +=1'''
    
    #experiment 6 target and one prev word and sentiment score
    '''for i in range(len(character_doc)):
        if i>0:
            word = character_doc[i-1] +'@'+ senti_list[i-1]+'_'+character_doc[i]+'@'+senti_list[i]
            wordlist1.append(word)

    word_counts = Counter(wordlist1)
    word_counts = dict(word_counts)
    for a in word_counts:
        counts[a] = 0
        counts[a] +=1'''
        
    #experiment 7 target word, tag and separated counter for gender i.e add another key and value - gender:1 for male
    for i in range(len(character_doc)):
        word = character_doc[i] +'@'+ tag[i]
        wordlist1.append(word)

    word_counts = Counter(wordlist1)
    word_counts = dict(word_counts)
    for a in word_counts:
        counts[a] = 0
        counts[a] +=1  

    
    #add gender feature, male=1, female=0
    #gender = 0
    #genders ={'SHIRLEY': 'FEMALE', 'JACK': 'MALE', 'RONNIE': 'FEMALE', 'TANYA': 'FEMALE', 'SEAN': 'MALE', 'ROXY': 'FEMALE', 'HEATHER': 'FEMALE', 'MAX': 'MALE', 'IAN': 'MALE', 'JANE': 'FEMALE', 'STACEY': 'FEMALE', 'PHIL': 'MALE', 'MINTY': 'MALE', 'CHRISTIAN': 'MALE', 'CLARE': 'FEMALE'}

    #for item in genders:
        #if name == item:
            #gender = genders[name]
            #if gender == "MALE":
                #gender =1
            #else: gender =0
    #counts.update({"Gender": gender})
    
    return counts
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\dandi\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# Requirement already satisfied: afinn in c:\users\dandi\anaconda3\lib\site-packages (0.1)

# %%
#updated version3
# changes made from original version: tag and name are parsed to 
#to_feature_vector_dictionary2()

corpusVectorizer = DictVectorizer()   # corpusVectorizor which will just produce sparse vectors from feature dicts

def create_document_matrix_from_corpus2(corpus,tag, fitting=False):
    """Method which fits different vectorizers
    on data and returns a matrix.
    
    Currently just does simple conversion to matrix by vectorizing the dictionary. Improve this for Q3.
    
    ::corpus:: a list of (class_label, document) pairs.
    ::fitting:: a boolean indicating whether to fit/train the vectorizers (should be true on training data)
    """
    
    # uses the global variable of the corpus Vectorizer to improve things
    if fitting:
        corpusVectorizer.fit([to_feature_vector_dictionary2(a[1],b[1],a[0]) for a, b in zip(corpus,tag)])

    doc_feature_matrix = corpusVectorizer.transform([to_feature_vector_dictionary2(a[1],b[1],a[0]) for a, b, in zip(corpus,tag)])
    
    #training_feature_matrix[0].toarray()
    return doc_feature_matrix

training_feature_matrix = create_document_matrix_from_corpus2(training_corpus, training_POS, fitting=True)

# %%
training_feature_matrix
# Out:
# <16x5795 sparse matrix of type '<class 'numpy.float64'>'
# 	with 15005 stored elements in Compressed Sparse Row format>

# %%
# get the test data- only 40 lines used for each character
test_character_docs = create_character_document_from_dataframe(test_data, max_line_count=40)
print('Num. Characters: ',len(val_character_docs.keys()),"\n")
total_words = 0
for name in test_character_docs.keys():
    print(name, 'Num of Words: ',len(test_character_docs[name].split()))
    total_words += len(test_character_docs[name].split())
print("total words", total_words)

# create list of pairs of (character name, pre-processed character) 
test_corpus = [(name, pre_process1(doc)[0]) for name, doc in sorted(test_character_docs.items())]
test_labels = [name for name, doc in test_corpus]
# create list of pairs of (character name, POS tags) 
test_POS = [(name, pre_process1(doc)[1]) for name, doc in sorted(test_character_docs.items())]
# Out:
# name-gender mapping:  {'SHIRLEY': 'FEMALE', 'HEATHER': 'FEMALE', 'PHIL': 'MALE', 'SEAN': 'MALE', 'TANYA': 'FEMALE', 'MAX': 'MALE', 'JACK': 'MALE', 'IAN': 'MALE', 'JANE': 'FEMALE', 'STACEY': 'FEMALE', 'ROXY': 'FEMALE', 'RONNIE': 'FEMALE', 'CHRISTIAN': 'MALE', 'MINTY': 'MALE', 'CLARE': 'FEMALE'}
#
# lines per character {'SHIRLEY': 40, 'OTHER': 40, 'HEATHER': 40, 'PHIL': 40, 'SEAN': 40, 'TANYA': 40, 'MAX': 40, 'JACK': 40, 'IAN': 40, 'JANE': 40, 'STACEY': 40, 'ROXY': 40, 'RONNIE': 40, 'CHRISTIAN': 40, 'MINTY': 40, 'CLARE': 40}
# Num. Characters:  16
#
# SHIRLEY Num of Words:  373
# OTHER Num of Words:  453
# HEATHER Num of Words:  451
# PHIL Num of Words:  406
# SEAN Num of Words:  466
# TANYA Num of Words:  465
# MAX Num of Words:  494
# JACK Num of Words:  412
# IAN Num of Words:  509
# JANE Num of Words:  414
# STACEY Num of Words:  634
# ROXY Num of Words:  392
# RONNIE Num of Words:  390
# CHRISTIAN Num of Words:  629
# MINTY Num of Words:  428
# CLARE Num of Words:  368
# total words 7284

# %%
# Just transform the test_feature_matrix, don't fit
test_feature_matrix = create_document_matrix_from_corpus2(test_corpus,test_POS,fitting=False)

# %%
test_feature_matrix
# Out:
# <16x5795 sparse matrix of type '<class 'numpy.float64'>'
# 	with 2343 stored elements in Compressed Sparse Row format>

# %%
def compute_cosine_similarity(v1, v2):
    """Takes a pair of vectors v1 and v2 (1-d arrays e.g. [0, 0.5, 0.5])
    returns the cosine similarity between the vectors
    """
    
    # compute cosine similarity manually
    manual_cosine_similarity = np.dot(v1, v2)  /(norm(v1) * norm(v2))
    
    return manual_cosine_similarity

# %%
def compute_IR_evaluation_scores(train_feature_matrix, test_feature_matrix, train_labels, test_labels):
    """
    Computes an information retrieval based on training data feature matrix and test data feature matrix
    returns 4-tuple:
    ::mean_rank:: mean of the ranking of the target document in terms of similarity to the query/test document
    1 is the best possible score.
    ::mean_cosine_similarity:: mean cosine similarity score for the target document vs. the test document of the same class
    ::accuracy:: proportion of test documents correctly classified
    ::df:: a data frame with all the similarity measures of the test documents vs. train documents
    
    params:
    ::train_feature_matrix:: a numpy matrix N x M shape where N = number of characters M = number of features
    ::test_feature_matrix::  a numpy matrix N x M shape where N = number of characters M = number of features
    ::train_labels:: a list of character names for the training data in order consistent with train_feature_matrix
    ::test_labels:: a list of character names for the test data in order consistent with test_feature_matrix
    """
    rankings = []
    all_cosine_similarities = []
    pairwise_cosine_similarity = []
    pairs = []
    correct = 0
    for i, target in enumerate(test_labels):
        # compare the left out character against the mean
        idx = i 
        fm_1 = test_feature_matrix.toarray()[idx]
        all_sims = {}
        # print("target:", target)
        for j, other in enumerate(train_labels):
            fm_2 = train_feature_matrix.toarray()[j]
            manual_cosine_similarity = compute_cosine_similarity(fm_1, fm_2)
            pairs.append((target, other))
            pairwise_cosine_similarity.append(manual_cosine_similarity)
            if other == target:
                all_cosine_similarities.append(manual_cosine_similarity)
            all_sims[other] = manual_cosine_similarity

            # print(target, other, manual_cosine_similarity)
        sorted_similarities = sorted(all_sims.items(),key=lambda x:x[1],reverse=True)
        # print(sorted_similarities)
        ranking = {key[0]: rank for rank, key in enumerate(sorted_similarities, 1)}
        # print("Ranking for target", ranking[target])
        if ranking[target] == 1:
            correct += 1
        rankings.append(ranking[target])
        # print("*****")
    mean_rank = np.mean(rankings)
    mean_cosine_similarity = np.mean(all_cosine_similarities)
    accuracy = correct/len(test_labels)
    print("mean rank", np.mean(rankings))
    print("mean cosine similarity", mean_cosine_similarity)
    print(correct, "correct out of", len(test_labels), "/ accuracy:", accuracy )
    
    # get a dafaframe showing all the similarity scores of training vs test docs
    df = pd.DataFrame({'doc1': [x[0] for x in pairs], 'doc2': [x[1] for x in pairs],
                       'similarity': pairwise_cosine_similarity})

    # display characters which are most similar and least similar
    df.loc[[df.similarity.values.argmax(), df.similarity.values.argmin()]]
    return (mean_rank, mean_cosine_similarity, accuracy, df)

# %%
def plot_heat_map_similarity(df):
    """Takes a dataframe with header 'doc1, doc2, similarity'
    Plots a heatmap based on the similarity scores.
    """
    test_labels =  sorted(list(set(df.sort_values(['doc1'])['doc1'])))
    # add padding 1.0 values to either side
    cm = [[1.0,] * (len(test_labels)+2)]
    for target in test_labels:
        new_row = [1.0]
        for x in df.sort_values(['doc1', 'doc2'])[df['doc1']==target]['similarity']:
            new_row.append(x)
        new_row.append(1.0)
        cm.append(new_row)
    cm.append([1.0,] * (len(test_labels)+2))
    #print(cm)
    labels = [""] + test_labels + [""]
    fig = plt.figure(figsize=(20,20))
    ax = fig.add_subplot(111)
    cax = ax.matshow(cm)
    plt.title('Similarity matrix between documents as vectors')
    fig.colorbar(cax)
    ax.set_xticks(np.arange(len(labels)))
    ax.set_yticks(np.arange(len(labels)))
    ax.set_xticklabels( labels, rotation=45)
    ax.set_yticklabels( labels)

    for i in range(len(cm)):
        for j in range(len(cm)):

            text = ax.text(j, i, round(cm[i][j],3),
                           ha="center", va="center", color="w")

    plt.xlabel('Training Vector Doc')
    plt.ylabel('Test Vector Doc')
    #fig.tight_layout()
    plt.show()

# %%
mean_rank, mean_cosine_simliarity, acc, df = compute_IR_evaluation_scores(training_feature_matrix, test_feature_matrix, train_labels, test_labels)
# Out:
# mean rank 2.25
# mean cosine similarity 0.28408187907385607
# 9 correct out of 16 / accuracy: 0.5625

# %%
#for loop to iterate different k to find the best features 
from sklearn.feature_selection import SelectKBest, chi2
for i in range(0,training_feature_matrix.shape[1],50):
    if i>0:
        selector =  SelectKBest(chi2,k=i)
        training_feature_matrix2 = selector.fit(training_feature_matrix, train_labels)
        features_train_transformed = selector.transform(training_feature_matrix)
    
        #val_feature_matrix2 = selector.fit(val_feature_matrix, val_labels)
        features_test_transformed = selector.transform(test_feature_matrix)
        print('k= ',i, 'mean rank: ', compute_IR_evaluation_scores(features_train_transformed, features_test_transformed, train_labels, test_labels)[0] )
# Out:
# <ipython-input-104-f74403f14492>:7: RuntimeWarning: invalid value encountered in double_scalars
#   manual_cosine_similarity = np.dot(v1, v2)  /(norm(v1) * norm(v2))
# <ipython-input-104-f74403f14492>:7: RuntimeWarning: invalid value encountered in double_scalars
#   manual_cosine_similarity = np.dot(v1, v2)  /(norm(v1) * norm(v2))
# <ipython-input-104-f74403f14492>:7: RuntimeWarning: invalid value encountered in double_scalars
#   manual_cosine_similarity = np.dot(v1, v2)  /(norm(v1) * norm(v2))
# <ipython-input-104-f74403f14492>:7: RuntimeWarning: invalid value encountered in double_scalars
#   manual_cosine_similarity = np.dot(v1, v2)  /(norm(v1) * norm(v2))
# <ipython-input-104-f74403f14492>:7: RuntimeWarning: invalid value encountered in double_scalars
#   manual_cosine_similarity = np.dot(v1, v2)  /(norm(v1) * norm(v2))
# <ipython-input-104-f74403f14492>:7: RuntimeWarning: invalid value encountered in double_scalars
#   manual_cosine_similarity = np.dot(v1, v2)  /(norm(v1) * norm(v2))
# <ipython-input-104-f74403f14492>:7: RuntimeWarning: invalid value encountered in double_scalars
#   manual_cosine_similarity = np.dot(v1, v2)  /(norm(v1) * norm(v2))
# <ipython-input-104-f74403f14492>:7: RuntimeWarning: invalid value encountered in double_scalars
#   manual_cosine_similarity = np.dot(v1, v2)  /(norm(v1) * norm(v2))
# <ipython-input-104-f74403f14492>:7: RuntimeWarning: invalid value encountered in double_scalars
#   manual_cosine_similarity = np.dot(v1, v2)  /(norm(v1) * norm(v2))
# <ipython-input-104-f74403f14492>:7: RuntimeWarning: invalid value encountered in double_scalars
#   manual_cosine_similarity = np.dot(v1, v2)  /(norm(v1) * norm(v2))
# <ipython-input-104-f74403f14492>:7: RuntimeWarning: invalid value encountered in double_scalars
#   manual_cosine_similarity = np.dot(v1, v2)  /(norm(v1) * norm(v2))
# <ipython-input-104-f74403f14492>:7: RuntimeWarning: invalid value encountered in double_scalars
#   manual_cosine_similarity = np.dot(v1, v2)  /(norm(v1) * norm(v2))
# <ipython-input-104-f74403f14492>:7: RuntimeWarning: invalid value encountered in double_scalars
#   manual_cosine_similarity = np.dot(v1, v2)  /(norm(v1) * norm(v2))
# <ipython-input-104-f74403f14492>:7: RuntimeWarning: invalid value encountered in double_scalars
#   manual_cosine_similarity = np.dot(v1, v2)  /(norm(v1) * norm(v2))
# <ipython-input-104-f74403f14492>:7: RuntimeWarning: invalid value encountered in double_scalars
#   manual_cosine_similarity = np.dot(v1, v2)  /(norm(v1) * norm(v2))
# mean rank 8.5
# mean cosine similarity nan
# 1 correct out of 16 / accuracy: 0.0625
# k=  50 mean rank:  8.5
# mean rank 8.5
# mean cosine similarity nan
# 1 correct out of 16 / accuracy: 0.0625
# k=  100 mean rank:  8.5
# mean rank 8.5
# mean cosine similarity nan
# 2 correct out of 16 / accuracy: 0.125
# k=  150 mean rank:  8.5
# mean rank 8.625
# mean cosine similarity nan
# 2 correct out of 16 / accuracy: 0.125
# k=  200 mean rank:  8.625
# mean rank 8.6875
# mean cosine similarity nan
# 2 correct out of 16 / accuracy: 0.125
# k=  250 mean rank:  8.6875
# mean rank 8.375
# mean cosine similarity nan
# 3 correct out of 16 / accuracy: 0.1875
# k=  300 mean rank:  8.375
# mean rank 8.25
# mean cosine similarity nan
# 3 correct out of 16 / accuracy: 0.1875
# k=  350 mean rank:  8.25
# mean rank 8.375
# mean cosine similarity nan
# 2 correct out of 16 / accuracy: 0.125
# k=  400 mean rank:  8.375
# mean rank 7.5625
# mean cosine similarity nan
# 2 correct out of 16 / accuracy: 0.125
# k=  450 mean rank:  7.5625
# mean rank 7.5625
# mean cosine similarity nan
# 2 correct out of 16 / accuracy: 0.125
# k=  500 mean rank:  7.5625
# mean rank 7.625
# mean cosine similarity nan
# 2 correct out of 16 / accuracy: 0.125
# k=  550 mean rank:  7.625
# mean rank 7.6875
# mean cosine similarity nan
# 2 correct out of 16 / accuracy: 0.125
# k=  600 mean rank:  7.6875
# mean rank 7.8125
# mean cosine similarity nan
# 2 correct out of 16 / accuracy: 0.125
# k=  650 mean rank:  7.8125
# mean rank 7.875
# mean cosine similarity nan
# 2 correct out of 16 / accuracy: 0.125
# k=  700 mean rank:  7.875
# mean rank 7.875
# mean cosine similarity nan
# 2 correct out of 16 / accuracy: 0.125
# k=  750 mean rank:  7.875
# mean rank 8.0
# mean cosine similarity nan
# 2 correct out of 16 / accuracy: 0.125
# k=  800 mean rank:  8.0
# mean rank 7.6875
# mean cosine similarity nan
# 3 correct out of 16 / accuracy: 0.1875
# k=  850 mean rank:  7.6875
# mean rank 7.75
# mean cosine similarity nan
# 2 correct out of 16 / accuracy: 0.125
# k=  900 mean rank:  7.75
# mean rank 7.625
# mean cosine similarity nan
# 3 correct out of 16 / accuracy: 0.1875
# k=  950 mean rank:  7.625
# mean rank 7.0
# mean cosine similarity nan
# 3 correct out of 16 / accuracy: 0.1875
# k=  1000 mean rank:  7.0
# mean rank 6.1875
# mean cosine similarity nan
# 3 correct out of 16 / accuracy: 0.1875
# k=  1050 mean rank:  6.1875
# mean rank 6.25
# mean cosine similarity nan
# 3 correct out of 16 / accuracy: 0.1875
# k=  1100 mean rank:  6.25
# mean rank 6.125
# mean cosine similarity nan
# 4 correct out of 16 / accuracy: 0.25
# k=  1150 mean rank:  6.125
# mean rank 5.9375
# mean cosine similarity nan
# 5 correct out of 16 / accuracy: 0.3125
# k=  1200 mean rank:  5.9375
# mean rank 5.875
# mean cosine similarity nan
# 6 correct out of 16 / accuracy: 0.375
# k=  1250 mean rank:  5.875
# mean rank 6.0625
# mean cosine similarity nan
# 5 correct out of 16 / accuracy: 0.3125
# k=  1300 mean rank:  6.0625
# mean rank 5.9375
# mean cosine similarity 0.04425458519852779
# 5 correct out of 16 / accuracy: 0.3125
# k=  1350 mean rank:  5.9375
# <ipython-input-104-f74403f14492>:7: RuntimeWarning: invalid value encountered in double_scalars
#   manual_cosine_similarity = np.dot(v1, v2)  /(norm(v1) * norm(v2))
# <ipython-input-104-f74403f14492>:7: RuntimeWarning: invalid value encountered in double_scalars
#   manual_cosine_similarity = np.dot(v1, v2)  /(norm(v1) * norm(v2))
# <ipython-input-104-f74403f14492>:7: RuntimeWarning: invalid value encountered in double_scalars
#   manual_cosine_similarity = np.dot(v1, v2)  /(norm(v1) * norm(v2))
# <ipython-input-104-f74403f14492>:7: RuntimeWarning: invalid value encountered in double_scalars
#   manual_cosine_similarity = np.dot(v1, v2)  /(norm(v1) * norm(v2))
# <ipython-input-104-f74403f14492>:7: RuntimeWarning: invalid value encountered in double_scalars
#   manual_cosine_similarity = np.dot(v1, v2)  /(norm(v1) * norm(v2))
# <ipython-input-104-f74403f14492>:7: RuntimeWarning: invalid value encountered in double_scalars
#   manual_cosine_similarity = np.dot(v1, v2)  /(norm(v1) * norm(v2))
# <ipython-input-104-f74403f14492>:7: RuntimeWarning: invalid value encountered in double_scalars
#   manual_cosine_similarity = np.dot(v1, v2)  /(norm(v1) * norm(v2))
# <ipython-input-104-f74403f14492>:7: RuntimeWarning: invalid value encountered in double_scalars
#   manual_cosine_similarity = np.dot(v1, v2)  /(norm(v1) * norm(v2))
# <ipython-input-104-f74403f14492>:7: RuntimeWarning: invalid value encountered in double_scalars
#   manual_cosine_similarity = np.dot(v1, v2)  /(norm(v1) * norm(v2))
# <ipython-input-104-f74403f14492>:7: RuntimeWarning: invalid value encountered in double_scalars
#   manual_cosine_similarity = np.dot(v1, v2)  /(norm(v1) * norm(v2))
# <ipython-input-104-f74403f14492>:7: RuntimeWarning: invalid value encountered in double_scalars
#   manual_cosine_similarity = np.dot(v1, v2)  /(norm(v1) * norm(v2))
# mean rank 5.875
# mean cosine similarity 0.04514847783991911
# 6 correct out of 16 / accuracy: 0.375
# k=  1400 mean rank:  5.875
# mean rank 5.875
# mean cosine similarity 0.04763525813617664
# 7 correct out of 16 / accuracy: 0.4375
# k=  1450 mean rank:  5.875
# mean rank 5.9375
# mean cosine similarity 0.0467600818712719
# 6 correct out of 16 / accuracy: 0.375
# k=  1500 mean rank:  5.9375
# mean rank 5.9375
# mean cosine similarity 0.046026775745138
# 6 correct out of 16 / accuracy: 0.375
# k=  1550 mean rank:  5.9375
# mean rank 5.9375
# mean cosine similarity 0.04696019649708574
# 6 correct out of 16 / accuracy: 0.375
# k=  1600 mean rank:  5.9375
# mean rank 5.3125
# mean cosine similarity 0.051014347538185845
# 7 correct out of 16 / accuracy: 0.4375
# k=  1650 mean rank:  5.3125
# mean rank 5.1875
# mean cosine similarity 0.052231439140724395
# 7 correct out of 16 / accuracy: 0.4375
# k=  1700 mean rank:  5.1875
# mean rank 5.125
# mean cosine similarity 0.05334230377037211
# 8 correct out of 16 / accuracy: 0.5
# k=  1750 mean rank:  5.125
# mean rank 5.125
# mean cosine similarity 0.05449184960368413
# 8 correct out of 16 / accuracy: 0.5
# k=  1800 mean rank:  5.125
# mean rank 4.5
# mean cosine similarity 0.056820117271855076
# 9 correct out of 16 / accuracy: 0.5625
# k=  1850 mean rank:  4.5
# mean rank 3.8125
# mean cosine similarity 0.05887655786034671
# 8 correct out of 16 / accuracy: 0.5
# k=  1900 mean rank:  3.8125
# mean rank 3.8125
# mean cosine similarity 0.0577968388610571
# 8 correct out of 16 / accuracy: 0.5
# k=  1950 mean rank:  3.8125
# mean rank 3.75
# mean cosine similarity 0.05673215344269006
# 8 correct out of 16 / accuracy: 0.5
# k=  2000 mean rank:  3.75
# mean rank 3.75
# mean cosine similarity 0.054344149602584754
# 8 correct out of 16 / accuracy: 0.5
# k=  2050 mean rank:  3.75
# mean rank 3.8125
# mean cosine similarity 0.05345135947660046
# 8 correct out of 16 / accuracy: 0.5
# k=  2100 mean rank:  3.8125
# mean rank 3.875
# mean cosine similarity 0.05255508751891516
# 7 correct out of 16 / accuracy: 0.4375
# k=  2150 mean rank:  3.875
# mean rank 3.8125
# mean cosine similarity 0.05163221431133032
# 8 correct out of 16 / accuracy: 0.5
# k=  2200 mean rank:  3.8125
# mean rank 3.3125
# mean cosine similarity 0.054462447036319174
# 8 correct out of 16 / accuracy: 0.5
# k=  2250 mean rank:  3.3125
# mean rank 3.375
# mean cosine similarity 0.053303058641665485
# 8 correct out of 16 / accuracy: 0.5
# k=  2300 mean rank:  3.375
# mean rank 3.3125
# mean cosine similarity 0.052198196120938276
# 8 correct out of 16 / accuracy: 0.5
# k=  2350 mean rank:  3.3125
# mean rank 3.25
# mean cosine similarity 0.052640409237353455
# 8 correct out of 16 / accuracy: 0.5
# k=  2400 mean rank:  3.25
# mean rank 3.375
# mean cosine similarity 0.052082043883725254
# 7 correct out of 16 / accuracy: 0.4375
# k=  2450 mean rank:  3.375
# mean rank 3.375
# mean cosine similarity 0.051528661796292036
# 7 correct out of 16 / accuracy: 0.4375
# k=  2500 mean rank:  3.375
# mean rank 3.375
# mean cosine similarity 0.05253731955118029
# 7 correct out of 16 / accuracy: 0.4375
# k=  2550 mean rank:  3.375
# mean rank 3.375
# mean cosine similarity 0.052714593450580355
# 7 correct out of 16 / accuracy: 0.4375
# k=  2600 mean rank:  3.375
# mean rank 3.5
# mean cosine similarity 0.05174151413309737
# 6 correct out of 16 / accuracy: 0.375
# k=  2650 mean rank:  3.5
# mean rank 3.5
# mean cosine similarity 0.05048680317136049
# 6 correct out of 16 / accuracy: 0.375
# k=  2700 mean rank:  3.5
# mean rank 3.1875
# mean cosine similarity 0.05284725413893785
# 9 correct out of 16 / accuracy: 0.5625
# k=  2750 mean rank:  3.1875
# mean rank 3.3125
# mean cosine similarity 0.05172051386734834
# 8 correct out of 16 / accuracy: 0.5
# k=  2800 mean rank:  3.3125
# mean rank 3.3125
# mean cosine similarity 0.05260859399606002
# 8 correct out of 16 / accuracy: 0.5
# k=  2850 mean rank:  3.3125
# mean rank 3.25
# mean cosine similarity 0.051730379658175854
# 8 correct out of 16 / accuracy: 0.5
# k=  2900 mean rank:  3.25
# mean rank 3.25
# mean cosine similarity 0.052481509606133306
# 9 correct out of 16 / accuracy: 0.5625
# k=  2950 mean rank:  3.25
# mean rank 3.25
# mean cosine similarity 0.051821054471613684
# 9 correct out of 16 / accuracy: 0.5625
# k=  3000 mean rank:  3.25
# mean rank 3.5
# mean cosine similarity 0.050349914280963956
# 7 correct out of 16 / accuracy: 0.4375
# k=  3050 mean rank:  3.5
# mean rank 3.4375
# mean cosine similarity 0.0512509630662864
# 8 correct out of 16 / accuracy: 0.5
# k=  3100 mean rank:  3.4375
# mean rank 3.4375
# mean cosine similarity 0.052158639618511776
# 8 correct out of 16 / accuracy: 0.5
# k=  3150 mean rank:  3.4375
# mean rank 3.4375
# mean cosine similarity 0.051794615690821624
# 8 correct out of 16 / accuracy: 0.5
# k=  3200 mean rank:  3.4375
# mean rank 3.4375
# mean cosine similarity 0.0504115400475251
# 8 correct out of 16 / accuracy: 0.5
# k=  3250 mean rank:  3.4375
# mean rank 3.5
# mean cosine similarity 0.04954374776663212
# 8 correct out of 16 / accuracy: 0.5
# k=  3300 mean rank:  3.5
# mean rank 3.5
# mean cosine similarity 0.04896524478285218
# 8 correct out of 16 / accuracy: 0.5
# k=  3350 mean rank:  3.5
# mean rank 3.5
# mean cosine similarity 0.048505001530988356
# 8 correct out of 16 / accuracy: 0.5
# k=  3400 mean rank:  3.5
# mean rank 2.875
# mean cosine similarity 0.049392775108090814
# 8 correct out of 16 / accuracy: 0.5
# k=  3450 mean rank:  2.875
# mean rank 2.3125
# mean cosine similarity 0.05060662255949521
# 8 correct out of 16 / accuracy: 0.5
# k=  3500 mean rank:  2.3125
# mean rank 2.625
# mean cosine similarity 0.052745939155818836
# 7 correct out of 16 / accuracy: 0.4375
# k=  3550 mean rank:  2.625
# mean rank 2.5625
# mean cosine similarity 0.05378050590482969
# 8 correct out of 16 / accuracy: 0.5
# k=  3600 mean rank:  2.5625
# mean rank 2.4375
# mean cosine similarity 0.052944623943847566
# 7 correct out of 16 / accuracy: 0.4375
# k=  3650 mean rank:  2.4375
# mean rank 2.4375
# mean cosine similarity 0.054329465817116195
# 7 correct out of 16 / accuracy: 0.4375
# k=  3700 mean rank:  2.4375
# mean rank 2.5625
# mean cosine similarity 0.05262590189903375
# 7 correct out of 16 / accuracy: 0.4375
# k=  3750 mean rank:  2.5625
# mean rank 2.25
# mean cosine similarity 0.05641453661978811
# 9 correct out of 16 / accuracy: 0.5625
# k=  3800 mean rank:  2.25
# mean rank 2.5625
# mean cosine similarity 0.05492717356735287
# 8 correct out of 16 / accuracy: 0.5
# k=  3850 mean rank:  2.5625
# mean rank 2.375
# mean cosine similarity 0.05678313595967001
# 9 correct out of 16 / accuracy: 0.5625
# k=  3900 mean rank:  2.375
# mean rank 2.4375
# mean cosine similarity 0.05809195688712721
# 10 correct out of 16 / accuracy: 0.625
# k=  3950 mean rank:  2.4375
# mean rank 2.625
# mean cosine similarity 0.057967967656887665
# 9 correct out of 16 / accuracy: 0.5625
# k=  4000 mean rank:  2.625
# mean rank 2.5
# mean cosine similarity 0.05834884848350815
# 10 correct out of 16 / accuracy: 0.625
# k=  4050 mean rank:  2.5
# mean rank 2.5
# mean cosine similarity 0.058619653039064856
# 10 correct out of 16 / accuracy: 0.625
# k=  4100 mean rank:  2.5
# mean rank 2.4375
# mean cosine similarity 0.05908674089211027
# 11 correct out of 16 / accuracy: 0.6875
# k=  4150 mean rank:  2.4375
# mean rank 2.5625
# mean cosine similarity 0.05770262971056632
# 11 correct out of 16 / accuracy: 0.6875
# k=  4200 mean rank:  2.5625
# mean rank 2.625
# mean cosine similarity 0.060479632544079044
# 11 correct out of 16 / accuracy: 0.6875
# k=  4250 mean rank:  2.625
# mean rank 2.75
# mean cosine similarity 0.058999452867847274
# 10 correct out of 16 / accuracy: 0.625
# k=  4300 mean rank:  2.75
# mean rank 2.5625
# mean cosine similarity 0.058498419487524767
# 10 correct out of 16 / accuracy: 0.625
# k=  4350 mean rank:  2.5625
# mean rank 2.4375
# mean cosine similarity 0.062031046967167026
# 12 correct out of 16 / accuracy: 0.75
# k=  4400 mean rank:  2.4375
# mean rank 2.25
# mean cosine similarity 0.06310076820360783
# 11 correct out of 16 / accuracy: 0.6875
# k=  4450 mean rank:  2.25
# mean rank 2.375
# mean cosine similarity 0.0653465187510844
# 11 correct out of 16 / accuracy: 0.6875
# k=  4500 mean rank:  2.375
# mean rank 2.1875
# mean cosine similarity 0.06860816234824524
# 12 correct out of 16 / accuracy: 0.75
# k=  4550 mean rank:  2.1875
# mean rank 2.1875
# mean cosine similarity 0.06899941584951441
# 13 correct out of 16 / accuracy: 0.8125
# k=  4600 mean rank:  2.1875
# mean rank 2.0625
# mean cosine similarity 0.0696197464969338
# 12 correct out of 16 / accuracy: 0.75
# k=  4650 mean rank:  2.0625
# mean rank 2.0
# mean cosine similarity 0.06890882427985281
# 12 correct out of 16 / accuracy: 0.75
# k=  4700 mean rank:  2.0
# mean rank 1.9375
# mean cosine similarity 0.0682957679720563
# 9 correct out of 16 / accuracy: 0.5625
# k=  4750 mean rank:  1.9375
# mean rank 1.875
# mean cosine similarity 0.07114652325625925
# 10 correct out of 16 / accuracy: 0.625
# k=  4800 mean rank:  1.875
# mean rank 1.9375
# mean cosine similarity 0.07504240969296404
# 9 correct out of 16 / accuracy: 0.5625
# k=  4850 mean rank:  1.9375
# mean rank 1.9375
# mean cosine similarity 0.07565032874385509
# 8 correct out of 16 / accuracy: 0.5
# k=  4900 mean rank:  1.9375
# mean rank 1.8125
# mean cosine similarity 0.07839483340753775
# 10 correct out of 16 / accuracy: 0.625
# k=  4950 mean rank:  1.8125
# mean rank 1.6875
# mean cosine similarity 0.08309385345451331
# 10 correct out of 16 / accuracy: 0.625
# k=  5000 mean rank:  1.6875
# mean rank 1.5
# mean cosine similarity 0.08674731094371815
# 12 correct out of 16 / accuracy: 0.75
# k=  5050 mean rank:  1.5
# mean rank 1.375
# mean cosine similarity 0.0913846870962941
# 12 correct out of 16 / accuracy: 0.75
# k=  5100 mean rank:  1.375
# mean rank 1.375
# mean cosine similarity 0.09478991292014452
# 12 correct out of 16 / accuracy: 0.75
# k=  5150 mean rank:  1.375
# mean rank 1.4375
# mean cosine similarity 0.09758461632501887
# 12 correct out of 16 / accuracy: 0.75
# k=  5200 mean rank:  1.4375
# mean rank 1.4375
# mean cosine similarity 0.09966820928178358
# 11 correct out of 16 / accuracy: 0.6875
# k=  5250 mean rank:  1.4375
# mean rank 1.5625
# mean cosine similarity 0.10328654104585666
# 9 correct out of 16 / accuracy: 0.5625
# k=  5300 mean rank:  1.5625
# mean rank 1.5625
# mean cosine similarity 0.1084411674275087
# 9 correct out of 16 / accuracy: 0.5625
# k=  5350 mean rank:  1.5625
# mean rank 1.6875
# mean cosine similarity 0.11445600317100402
# 8 correct out of 16 / accuracy: 0.5
# k=  5400 mean rank:  1.6875
# mean rank 1.9375
# mean cosine similarity 0.11902567941521183
# 7 correct out of 16 / accuracy: 0.4375
# k=  5450 mean rank:  1.9375
# mean rank 1.75
# mean cosine similarity 0.12760302858736142
# 8 correct out of 16 / accuracy: 0.5
# k=  5500 mean rank:  1.75
# mean rank 1.75
# mean cosine similarity 0.14032493755775907
# 7 correct out of 16 / accuracy: 0.4375
# k=  5550 mean rank:  1.75
# mean rank 1.75
# mean cosine similarity 0.15305175001245655
# 7 correct out of 16 / accuracy: 0.4375
# k=  5600 mean rank:  1.75
# mean rank 1.75
# mean cosine similarity 0.16938178221155048
# 9 correct out of 16 / accuracy: 0.5625
# k=  5650 mean rank:  1.75
# mean rank 1.9375
# mean cosine similarity 0.19371517950786385
# 9 correct out of 16 / accuracy: 0.5625
# k=  5700 mean rank:  1.9375
# mean rank 2.1875
# mean cosine similarity 0.2375225681912057
# 9 correct out of 16 / accuracy: 0.5625
# k=  5750 mean rank:  2.1875

# %% [markdown]
# # Final evaluation: mean rank 1.4375

# %%
#the best solution
from sklearn.feature_selection import SelectKBest, chi2
selector =  SelectKBest(chi2,k=5250)
training_feature_matrix2 = selector.fit(training_feature_matrix, train_labels)
features_train_transformed = selector.transform(training_feature_matrix)
features_test_transformed = selector.transform(test_feature_matrix)
mean_rank, mean_cosine_simliarity, acc, df0 = compute_IR_evaluation_scores(features_train_transformed, features_test_transformed, train_labels, test_labels)
# Out:
# mean rank 1.4375
# mean cosine similarity 0.09966820928178358
# 11 correct out of 16 / accuracy: 0.6875
